# %%
import os
import pandas as pd
import xml.etree.ElementTree as ET

# data path
train_dir = r'C:\Users\xiaog\Desktop\Project\Datasets\dataset\split_70_20_10\train'
valid_dir = r'C:\Users\xiaog\Desktop\Project\Datasets\dataset\split_70_20_10\valid'
test_dir = r'C:\Users\xiaog\Desktop\Project\Datasets\dataset\split_70_20_10\test'

# %%
# get label
def get_label_from_xml(xml_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()
    objects = root.findall('object')

    # if exist "thermal_defect", return 1
    for obj in objects:
        if obj.find('name').text == 'thermal_defect':
            return "1" 

    return "0"  

# count defects
def count_defects_in_directory(data_dir):
    with_defect = 0
    without_defect = 0
    
    for root, _, files in os.walk(data_dir):
        for file in files:
            if file.endswith('.xml'):
                xml_path = os.path.join(root, file)
                img_path = os.path.join(root.replace('annotations', 'images'), file.replace('.xml', '.jpg'))

                if os.path.exists(img_path):  
                    label = get_label_from_xml(xml_path)  
                    if label == "1":
                        with_defect += 1
                    else:
                        without_defect += 1
    
    return with_defect, without_defect

def create_dataframe(data_dir):
    data = []
    
    for root, _, files in os.walk(data_dir):
        for file in files:
            if file.endswith('.xml'):
                xml_path = os.path.join(root, file)
                img_path = os.path.join(root.replace('annotations', 'images'), file.replace('.xml', '.jpg'))

                if os.path.exists(img_path): 
                    label = get_label_from_xml(xml_path) 
                    data.append([img_path, label])
    
    return pd.DataFrame(data, columns=['filepath', 'label'])

train_df = create_dataframe(train_dir)
valid_df = create_dataframe(valid_dir)
test_df = create_dataframe(test_dir)

print(f"Train set: {len(train_df)} images")
print(f"Valid set: {len(valid_df)} images")
print(f"Test set: {len(test_df)} images")

train_with_defect, train_without_defect = count_defects_in_directory(train_dir)
valid_with_defect, valid_without_defect = count_defects_in_directory(valid_dir)
test_with_defect, test_without_defect = count_defects_in_directory(test_dir)

print(f"Train set - defect: {train_with_defect}, no_defect: {train_without_defect}")
print(f"Valid set - defect: {valid_with_defect}, no_defect: {valid_without_defect}")
print(f"Test set - defect: {test_with_defect}, no_defect: {test_without_defect}")
# Out:
# Train set: 3748 images
# Valid set: 1071 images
# Test set: 533 images
# Train set - defect: 3321, no_defect: 427
# Valid set - defect: 942, no_defect: 129
# Test set - defect: 470, no_defect: 63

# %%
import matplotlib.pyplot as plt

def plot_class_distribution(ax, with_defect, without_defect, title):
    ax.bar(['With Defect', 'Without Defect'], [with_defect, without_defect])
    ax.set_title(title)
    ax.set_ylabel('Count')

# Create a figure and set up subplots (1 row, 3 columns)
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Plot for Train Set
plot_class_distribution(axs[0], train_with_defect, train_without_defect, 'Train Set')

# Plot for Valid Set
plot_class_distribution(axs[1], valid_with_defect, valid_without_defect, 'Valid Set')

# Plot for Test Set
plot_class_distribution(axs[2], test_with_defect, test_without_defect, 'Test Set')

# Adjust layout for better spacing
plt.tight_layout()

# Save the figure
save_dir = r"C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_70_20_10"
class_distribution_path = os.path.join(save_dir, 'class_distribution_split_70_20_10.png')
plt.savefig(class_distribution_path, dpi=600, bbox_inches='tight')

# Print the saved path
print(f"Class distribution saved at: {class_distribution_path}")

# Show the plot
plt.show()
# Out:
# Class distribution saved at: C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_70_20_10\class_distribution_split_70_20_10.png

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np
import os
from PIL import Image, ImageDraw, ImageFont

image_path = r"C:\Users\xiaog\Desktop\Project\Datasets\dataset\split_70_20_10\train\images\train_0307.jpg"
original_image = load_img(image_path, target_size=(640, 640))
original_array = img_to_array(original_image)
original_array = np.expand_dims(original_array, axis=0)

augmentation_methods = {
    "Horizontal Flip": ImageDataGenerator(horizontal_flip=True),
    "Rotation (30 deg)": ImageDataGenerator(rotation_range=30),
    "Zoom (20%)": ImageDataGenerator(zoom_range=0.2)
}

augmented_images = []
titles = []

for name, generator in augmentation_methods.items():
    aug_image = next(generator.flow(original_array, batch_size=1))[0]
    augmented_images.append(aug_image)
    titles.append(name)

save_dir = r"C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_70_20_10"
os.makedirs(save_dir, exist_ok=True)

image_list = [original_array[0] / 255.0] + [img / 255.0 for img in augmented_images]
titles = ["Original Image"] + titles
image_list_uint8 = [np.uint8(np.clip(img * 255, 0, 255)) for img in image_list]

img_height, img_width = image_list_uint8[0].shape[:2]
title_height = 60
padding = 40
combined_width = len(image_list_uint8) * img_width + (len(image_list_uint8) - 1) * padding
combined_height = img_height + title_height

combined_image = Image.new("RGB", (combined_width, combined_height), color=(255, 255, 255))

try:
    font = ImageFont.truetype("arial.ttf", 40)
except:
    font = ImageFont.load_default()

draw = ImageDraw.Draw(combined_image)

for i, (img_arr, title) in enumerate(zip(image_list_uint8, titles)):
    img_pil = Image.fromarray(img_arr)

    x_offset = i * (img_width + padding)
    combined_image.paste(img_pil, (x_offset, title_height))

    bbox = draw.textbbox((0, 0), title, font=font)
    text_width = bbox[2] - bbox[0]
    text_x = x_offset + (img_width - text_width) // 2
    draw.text((text_x, 10), title, fill=(0, 0, 0), font=font)


save_path_combined = os.path.join(save_dir, "combined_augmented_image.jpg")
combined_image.save(save_path_combined, dpi=(600, 600))

plt.imshow(combined_image)
plt.axis('off')
plt.title("Combined Image")
plt.show()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

train_datagen = ImageDataGenerator(
    rescale=1./255,  
    rotation_range=30,  
    width_shift_range=0.2,  
    height_shift_range=0.2,  
    shear_range=0.2,  
    zoom_range=0.2, 
    horizontal_flip=True  
)

valid_test_datagen = ImageDataGenerator(rescale=1./255)

# train generator
train_generator_70_20_10 = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col="filepath",
    y_col="label",
    target_size=(128, 128),
    batch_size=32,
    class_mode="categorical"  
)

# valid generator
valid_generator_70_20_10 = valid_test_datagen.flow_from_dataframe(
    dataframe=valid_df,
    x_col="filepath",
    y_col="label",
    target_size=(128, 128),
    batch_size=32,
    class_mode="categorical"
)

# test generator
test_generator_70_20_10 = valid_test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col="filepath",
    y_col="label",
    target_size=(128, 128),
    batch_size=32,
    class_mode="categorical",
    shuffle=False  
)

print(f"Train generator samples: {train_generator_70_20_10.samples}")
print(f"Valid generator samples: {valid_generator_70_20_10.samples}")
print(f"Test generator samples: {test_generator_70_20_10.samples}")
# Out:
# Found 3748 validated image filenames belonging to 2 classes.
# Found 1071 validated image filenames belonging to 2 classes.
# Found 533 validated image filenames belonging to 2 classes.
# Train generator samples: 3748
# Valid generator samples: 1071
# Test generator samples: 533

# %%
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
import tensorflow as tf

def inception_module(x, filters):
    # 1x1 Conv
    conv1x1 = Conv2D(filters, (1,1), padding='same', activation='relu')(x)
    
    # 3x3 Conv
    conv3x3 = Conv2D(filters, (3,3), padding='same', activation='relu')(x)
    
    # 5x5 Conv
    conv5x5 = Conv2D(filters, (5,5), padding='same', activation='relu')(x)
    
    pool = MaxPooling2D((3,3), strides=(1,1), padding='same')(x)
    pool = Conv2D(filters, (1,1), padding='same', activation='relu')(pool)
    
    merged = concatenate([conv1x1, conv3x3, conv5x5, pool], axis=-1)
    return merged

def attention_block(inputs):
    attention = Dense(1, activation='tanh')(inputs)    # (batch_size, seq_length, 1)
    attention = Flatten()(attention)                   # (batch_size, seq_length)
    attention = Activation('softmax')(attention)       # (batch_size, seq_length)
    attention = Reshape((inputs.shape[1], 1))(attention)  # (batch_size, seq_length, 1)
    
    context = Multiply()([inputs, attention])          # (batch_size, seq_length, features)
    return context


def build_model(input_shape=(128, 128, 3), num_classes=2):
    inputs = Input(shape=input_shape)
    x = inception_module(inputs, 32)
    x = MaxPooling2D(2)(x)
    x = inception_module(x, 64)
    x = MaxPooling2D(2)(x)
    x = inception_module(x, 128)
    x = GlobalAveragePooling2D()(x)

    x = Reshape((-1, 128))(x)  # sequence for LSTM
    x = Bidirectional(LSTM(64, return_sequences=True))(x)
    x = Dropout(0.3)(x)
    x = attention_block(x)
    x = GlobalAveragePooling1D()(x)

    x = Dense(64, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs=inputs, outputs=outputs)
    return model
    # Build the model
model = build_model(input_shape=(128, 128, 3), num_classes=2)

# Print the model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 3)  0           ['input_1[0][0]']
#
#  conv2d (Conv2D)                (None, 128, 128, 32  128         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 32  896         ['input_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 32  2432        ['input_1[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 32  128         ['max_pooling2d[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 128, 128, 12  0           ['conv2d[0][0]',
#                                 8)                                'conv2d_1[0][0]',
#                                                                   'conv2d_2[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0          ['concatenate[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 128)  0          ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 64)   8256        ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 64)   73792       ['max_pooling2d_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 64)   204864      ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 64)   8256        ['max_pooling2d_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 256)  0           ['conv2d_4[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_6[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 256)  0          ['concatenate_1[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 32, 32, 256)  0          ['max_pooling2d_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 128)  32896       ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 128)  295040      ['max_pooling2d_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 128)  819328      ['max_pooling2d_3[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 128)  32896       ['max_pooling2d_4[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 32, 32, 512)  0           ['conv2d_8[0][0]',
#                                                                   'conv2d_9[0][0]',
#                                                                   'conv2d_10[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['concatenate_2[0][0]']
#  alAveragePooling2D)
#
#  reshape (Reshape)              (None, 4, 128)       0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  bidirectional (Bidirectional)  (None, 4, 128)       98816       ['reshape[0][0]']
#
#  dropout (Dropout)              (None, 4, 128)       0           ['bidirectional[0][0]']
#
#  dense (Dense)                  (None, 4, 1)         129         ['dropout[0][0]']
#
#  flatten (Flatten)              (None, 4)            0           ['dense[0][0]']
#
#  activation (Activation)        (None, 4)            0           ['flatten[0][0]']
#
#  reshape_1 (Reshape)            (None, 4, 1)         0           ['activation[0][0]']
#
#  multiply (Multiply)            (None, 4, 128)       0           ['dropout[0][0]',
#                                                                   'reshape_1[0][0]']
#
#  global_average_pooling1d (Glob  (None, 128)         0           ['multiply[0][0]']
#  alAveragePooling1D)
#
#  dense_1 (Dense)                (None, 64)           8256        ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dropout_1 (Dropout)            (None, 64)           0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 2)            130         ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 1,586,243
# Trainable params: 1,586,243
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Precision, Recall

def focal_loss(gamma=2., alpha=0.75):
    """
    Focal Loss implementation for binary classification.

    Parameters:
        gamma (float): Focusing parameter. Default is 2.
        alpha (float): Weighting factor for class imbalance. Default is 0.75 for better focusing on less frequent class.

    Returns:
        loss (function): Focal loss function.
    """

    def focal_loss_fixed(y_true, y_pred):
        # Clip predictions to avoid log(0)
        y_pred = K.clip(y_pred, K.epsilon(), 1. - K.epsilon())

        # Calculate cross entropy
        cross_entropy = -y_true * K.log(y_pred)

        # Calculate modulating factor (1 - p_t) ^ gamma
        modulating_factor = K.pow(1 - y_pred, gamma)

        # Calculate the focal loss
        loss = alpha * modulating_factor * cross_entropy

        return K.sum(loss, axis=-1)

    return focal_loss_fixed

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

def compile_model(model, split_name="split_70_20_10"):
    model.compile(
        optimizer=Adam(learning_rate=1e-4),
        loss=focal_loss(gamma=2., alpha=0.75),
        metrics=[
            'accuracy', 
            Precision(name='precision'), 
            Recall(name='recall'), 
            'AUC']
    )

    callbacks = [
        EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True),
        ModelCheckpoint(
            filepath=f'models/best_model_{split_name}.h5',
            monitor='val_loss',
            save_best_only=True,
            mode='min',
            verbose=1
        ),
        ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=10, min_lr=1e-6)
    ]

    return callbacks

# %%
import pickle
import numpy as np 

def train_and_save_history(train_generator, valid_generator, split_name="split_70_20_10", epochs=50, batch_size=32):
    steps_per_epoch = train_generator.samples // batch_size
    validation_steps = valid_generator.samples // batch_size

    # compile model
    model = build_model() 

    callbacks = compile_model(model, split_name)

    history = model.fit(
        train_generator,
        steps_per_epoch=steps_per_epoch,
        validation_data=valid_generator,
        validation_steps=validation_steps,
        epochs=epochs,
        callbacks=callbacks
    )

   # save history
    history_path = f"models/history_{split_name}.pkl"
    with open(history_path, 'wb') as f: 
        pickle.dump(history.history, f)

    print(f"Train history for {split_name} saved as {history_path}")


# train `split_70_20_10` and save history
train_and_save_history(train_generator_70_20_10, valid_generator_70_20_10, split_name="split_70_20_10")
# Out:
# Epoch 1/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0829 - accuracy: 0.8711 - precision: 0.8711 - recall: 0.8711 - auc: 0.8904
# Epoch 1: val_loss improved from inf to 0.07311, saving model to models\best_model_split_70_20_10.h5
# 117/117 [==============================] - 130s 860ms/step - loss: 0.0829 - accuracy: 0.8711 - precision: 0.8711 - recall: 0.8711 - auc: 0.8904 - val_loss: 0.0731 - val_accuracy: 0.8797 - val_precision: 0.8797 - val_recall: 0.8797 - val_auc: 0.8958 - lr: 1.0000e-04
# Epoch 2/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0734 - accuracy: 0.8859 - precision: 0.8859 - recall: 0.8859 - auc: 0.8957
# Epoch 2: val_loss improved from 0.07311 to 0.06958, saving model to models\best_model_split_70_20_10.h5
# 117/117 [==============================] - 95s 805ms/step - loss: 0.0734 - accuracy: 0.8859 - precision: 0.8859 - recall: 0.8859 - auc: 0.8957 - val_loss: 0.0696 - val_accuracy: 0.8807 - val_precision: 0.8807 - val_recall: 0.8807 - val_auc: 0.9213 - lr: 1.0000e-04
# Epoch 3/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0702 - accuracy: 0.8859 - precision: 0.8859 - recall: 0.8859 - auc: 0.9085
# Epoch 3: val_loss improved from 0.06958 to 0.06711, saving model to models\best_model_split_70_20_10.h5
# 117/117 [==============================] - 100s 855ms/step - loss: 0.0702 - accuracy: 0.8859 - precision: 0.8859 - recall: 0.8859 - auc: 0.9085 - val_loss: 0.0671 - val_accuracy: 0.8797 - val_precision: 0.8797 - val_recall: 0.8797 - val_auc: 0.9235 - lr: 1.0000e-04
# Epoch 4/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0690 - accuracy: 0.8856 - precision: 0.8856 - recall: 0.8856 - auc: 0.9182
# Epoch 4: val_loss improved from 0.06711 to 0.06653, saving model to models\best_model_split_70_20_10.h5
# 117/117 [==============================] - 93s 793ms/step - loss: 0.0690 - accuracy: 0.8856 - precision: 0.8856 - recall: 0.8856 - auc: 0.9182 - val_loss: 0.0665 - val_accuracy: 0.8807 - val_precision: 0.8807 - val_recall: 0.8807 - val_auc: 0.9316 - lr: 1.0000e-04
# Epoch 5/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0673 - accuracy: 0.8862 - precision: 0.8862 - recall: 0.8862 - auc: 0.9216
# Epoch 5: val_loss improved from 0.06653 to 0.06478, saving model to models\best_model_split_70_20_10.h5
# 117/117 [==============================] - 98s 835ms/step - loss: 0.0673 - accuracy: 0.8862 - precision: 0.8862 - recall: 0.8862 - auc: 0.9216 - val_loss: 0.0648 - val_accuracy: 0.8816 - val_precision: 0.8816 - val_recall: 0.8816 - val_auc: 0.9375 - lr: 1.0000e-04
# Epoch 6/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0660 - accuracy: 0.8862 - precision: 0.8862 - recall: 0.8862 - auc: 0.9261
# Epoch 6: val_loss did not improve from 0.06478
# 117/117 [==============================] - 104s 887ms/step - loss: 0.0660 - accuracy: 0.8862 - precision: 0.8862 - recall: 0.8862 - auc: 0.9261 - val_loss: 0.0654 - val_accuracy: 0.8788 - val_precision: 0.8788 - val_recall: 0.8788 - val_auc: 0.9345 - lr: 1.0000e-04
# Epoch 7/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0652 - accuracy: 0.8854 - precision: 0.8854 - recall: 0.8854 - auc: 0.9312
# Epoch 7: val_loss improved from 0.06478 to 0.06305, saving model to models\best_model_split_70_20_10.h5
# 117/117 [==============================] - 95s 810ms/step - loss: 0.0652 - accuracy: 0.8854 - precision: 0.8854 - recall: 0.8854 - auc: 0.9312 - val_loss: 0.0631 - val_accuracy: 0.8797 - val_precision: 0.8797 - val_recall: 0.8797 - val_auc: 0.9405 - lr: 1.0000e-04
# Epoch 8/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0635 - accuracy: 0.8859 - precision: 0.8859 - recall: 0.8859 - auc: 0.9354
# Epoch 8: val_loss did not improve from 0.06305
# 117/117 [==============================] - 95s 813ms/step - loss: 0.0635 - accuracy: 0.8859 - precision: 0.8859 - recall: 0.8859 - auc: 0.9354 - val_loss: 0.0647 - val_accuracy: 0.8797 - val_precision: 0.8797 - val_recall: 0.8797 - val_auc: 0.9417 - lr: 1.0000e-04
# Epoch 9/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0649 - accuracy: 0.8862 - precision: 0.8862 - recall: 0.8862 - auc: 0.9316
# Epoch 9: val_loss improved from 0.06305 to 0.06134, saving model to models\best_model_split_70_20_10.h5
# 117/117 [==============================] - 97s 822ms/step - loss: 0.0649 - accuracy: 0.8862 - precision: 0.8862 - recall: 0.8862 - auc: 0.9316 - val_loss: 0.0613 - val_accuracy: 0.8807 - val_precision: 0.8807 - val_recall: 0.8807 - val_auc: 0.9427 - lr: 1.0000e-04
# Epoch 10/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0628 - accuracy: 0.8862 - precision: 0.8862 - recall: 0.8862 - auc: 0.9367
# Epoch 10: val_loss did not improve from 0.06134
# 117/117 [==============================] - 96s 820ms/step - loss: 0.0628 - accuracy: 0.8862 - precision: 0.8862 - recall: 0.8862 - auc: 0.9367 - val_loss: 0.0621 - val_accuracy: 0.8788 - val_precision: 0.8788 - val_recall: 0.8788 - val_auc: 0.9423 - lr: 1.0000e-04
# Epoch 11/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0620 - accuracy: 0.8864 - precision: 0.8864 - recall: 0.8864 - auc: 0.9380
# Epoch 11: val_loss improved from 0.06134 to 0.05992, saving model to models\best_model_split_70_20_10.h5
# 117/117 [==============================] - 101s 860ms/step - loss: 0.0620 - accuracy: 0.8864 - precision: 0.8864 - recall: 0.8864 - auc: 0.9380 - val_loss: 0.0599 - val_accuracy: 0.8797 - val_precision: 0.8797 - val_recall: 0.8797 - val_auc: 0.9426 - lr: 1.0000e-04
# Epoch 12/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0616 - accuracy: 0.8870 - precision: 0.8870 - recall: 0.8870 - auc: 0.9372
# Epoch 12: val_loss did not improve from 0.05992
# 117/117 [==============================] - 102s 870ms/step - loss: 0.0616 - accuracy: 0.8870 - precision: 0.8870 - recall: 0.8870 - auc: 0.9372 - val_loss: 0.0608 - val_accuracy: 0.8826 - val_precision: 0.8826 - val_recall: 0.8826 - val_auc: 0.9445 - lr: 1.0000e-04
# Epoch 13/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0608 - accuracy: 0.8875 - precision: 0.8875 - recall: 0.8875 - auc: 0.9391
# Epoch 13: val_loss improved from 0.05992 to 0.05903, saving model to models\best_model_split_70_20_10.h5
# 117/117 [==============================] - 97s 829ms/step - loss: 0.0608 - accuracy: 0.8875 - precision: 0.8875 - recall: 0.8875 - auc: 0.9391 - val_loss: 0.0590 - val_accuracy: 0.8920 - val_precision: 0.8920 - val_recall: 0.8920 - val_auc: 0.9431 - lr: 1.0000e-04
# Epoch 14/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0600 - accuracy: 0.8897 - precision: 0.8897 - recall: 0.8897 - auc: 0.9419
# Epoch 14: val_loss improved from 0.05903 to 0.05841, saving model to models\best_model_split_70_20_10.h5
# 117/117 [==============================] - 100s 855ms/step - loss: 0.0600 - accuracy: 0.8897 - precision: 0.8897 - recall: 0.8897 - auc: 0.9419 - val_loss: 0.0584 - val_accuracy: 0.8949 - val_precision: 0.8949 - val_recall: 0.8949 - val_auc: 0.9445 - lr: 1.0000e-04
# Epoch 15/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0588 - accuracy: 0.8929 - precision: 0.8929 - recall: 0.8929 - auc: 0.9438
# Epoch 15: val_loss improved from 0.05841 to 0.05787, saving model to models\best_model_split_70_20_10.h5
# 117/117 [==============================] - 102s 866ms/step - loss: 0.0588 - accuracy: 0.8929 - precision: 0.8929 - recall: 0.8929 - auc: 0.9438 - val_loss: 0.0579 - val_accuracy: 0.9025 - val_precision: 0.9025 - val_recall: 0.9025 - val_auc: 0.9448 - lr: 1.0000e-04
# Epoch 16/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0600 - accuracy: 0.8977 - precision: 0.8977 - recall: 0.8977 - auc: 0.9415
# Epoch 16: val_loss improved from 0.05787 to 0.05702, saving model to models\best_model_split_70_20_10.h5
# 117/117 [==============================] - 104s 883ms/step - loss: 0.0600 - accuracy: 0.8977 - precision: 0.8977 - recall: 0.8977 - auc: 0.9415 - val_loss: 0.0570 - val_accuracy: 0.9006 - val_precision: 0.9006 - val_recall: 0.9006 - val_auc: 0.9477 - lr: 1.0000e-04
# Epoch 17/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0589 - accuracy: 0.8977 - precision: 0.8977 - recall: 0.8977 - auc: 0.9438
# Epoch 17: val_loss did not improve from 0.05702
# 117/117 [==============================] - 101s 857ms/step - loss: 0.0589 - accuracy: 0.8977 - precision: 0.8977 - recall: 0.8977 - auc: 0.9438 - val_loss: 0.0618 - val_accuracy: 0.8835 - val_precision: 0.8835 - val_recall: 0.8835 - val_auc: 0.9435 - lr: 1.0000e-04
# Epoch 18/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0587 - accuracy: 0.8994 - precision: 0.8994 - recall: 0.8994 - auc: 0.9432
# Epoch 18: val_loss improved from 0.05702 to 0.05674, saving model to models\best_model_split_70_20_10.h5
# 117/117 [==============================] - 97s 829ms/step - loss: 0.0587 - accuracy: 0.8994 - precision: 0.8994 - recall: 0.8994 - auc: 0.9432 - val_loss: 0.0567 - val_accuracy: 0.8996 - val_precision: 0.8996 - val_recall: 0.8996 - val_auc: 0.9467 - lr: 1.0000e-04
# Epoch 19/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0584 - accuracy: 0.9039 - precision: 0.9039 - recall: 0.9039 - auc: 0.9448
# Epoch 19: val_loss improved from 0.05674 to 0.05592, saving model to models\best_model_split_70_20_10.h5
# 117/117 [==============================] - 98s 834ms/step - loss: 0.0584 - accuracy: 0.9039 - precision: 0.9039 - recall: 0.9039 - auc: 0.9448 - val_loss: 0.0559 - val_accuracy: 0.8996 - val_precision: 0.8996 - val_recall: 0.8996 - val_auc: 0.9499 - lr: 1.0000e-04
# Epoch 20/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0578 - accuracy: 0.9002 - precision: 0.9002 - recall: 0.9002 - auc: 0.9454
# Epoch 20: val_loss improved from 0.05592 to 0.05583, saving model to models\best_model_split_70_20_10.h5
# 117/117 [==============================] - 99s 842ms/step - loss: 0.0578 - accuracy: 0.9002 - precision: 0.9002 - recall: 0.9002 - auc: 0.9454 - val_loss: 0.0558 - val_accuracy: 0.9006 - val_precision: 0.9006 - val_recall: 0.9006 - val_auc: 0.9501 - lr: 1.0000e-04
# Epoch 21/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0577 - accuracy: 0.9015 - precision: 0.9015 - recall: 0.9015 - auc: 0.9452
# Epoch 21: val_loss improved from 0.05583 to 0.05517, saving model to models\best_model_split_70_20_10.h5
# 117/117 [==============================] - 102s 872ms/step - loss: 0.0577 - accuracy: 0.9015 - precision: 0.9015 - recall: 0.9015 - auc: 0.9452 - val_loss: 0.0552 - val_accuracy: 0.8977 - val_precision: 0.8977 - val_recall: 0.8977 - val_auc: 0.9509 - lr: 1.0000e-04
# Epoch 22/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0578 - accuracy: 0.9004 - precision: 0.9004 - recall: 0.9004 - auc: 0.9460
# Epoch 22: val_loss did not improve from 0.05517
# 117/117 [==============================] - 100s 857ms/step - loss: 0.0578 - accuracy: 0.9004 - precision: 0.9004 - recall: 0.9004 - auc: 0.9460 - val_loss: 0.0553 - val_accuracy: 0.8977 - val_precision: 0.8977 - val_recall: 0.8977 - val_auc: 0.9505 - lr: 1.0000e-04
# Epoch 23/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0556 - accuracy: 0.9042 - precision: 0.9042 - recall: 0.9042 - auc: 0.9498
# Epoch 23: val_loss did not improve from 0.05517
# 117/117 [==============================] - 99s 845ms/step - loss: 0.0556 - accuracy: 0.9042 - precision: 0.9042 - recall: 0.9042 - auc: 0.9498 - val_loss: 0.0556 - val_accuracy: 0.8949 - val_precision: 0.8949 - val_recall: 0.8949 - val_auc: 0.9513 - lr: 1.0000e-04
# Epoch 24/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0551 - accuracy: 0.9053 - precision: 0.9053 - recall: 0.9053 - auc: 0.9507
# Epoch 24: val_loss did not improve from 0.05517
# 117/117 [==============================] - 98s 837ms/step - loss: 0.0551 - accuracy: 0.9053 - precision: 0.9053 - recall: 0.9053 - auc: 0.9507 - val_loss: 0.0562 - val_accuracy: 0.8958 - val_precision: 0.8958 - val_recall: 0.8958 - val_auc: 0.9520 - lr: 1.0000e-04
# Epoch 25/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0570 - accuracy: 0.9012 - precision: 0.9012 - recall: 0.9012 - auc: 0.9482
# Epoch 25: val_loss did not improve from 0.05517
# 117/117 [==============================] - 100s 853ms/step - loss: 0.0570 - accuracy: 0.9012 - precision: 0.9012 - recall: 0.9012 - auc: 0.9482 - val_loss: 0.0565 - val_accuracy: 0.9025 - val_precision: 0.9025 - val_recall: 0.9025 - val_auc: 0.9490 - lr: 1.0000e-04
# Epoch 26/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0553 - accuracy: 0.9031 - precision: 0.9031 - recall: 0.9031 - auc: 0.9508
# Epoch 26: val_loss improved from 0.05517 to 0.05423, saving model to models\best_model_split_70_20_10.h5
# 117/117 [==============================] - 95s 812ms/step - loss: 0.0553 - accuracy: 0.9031 - precision: 0.9031 - recall: 0.9031 - auc: 0.9508 - val_loss: 0.0542 - val_accuracy: 0.8987 - val_precision: 0.8987 - val_recall: 0.8987 - val_auc: 0.9553 - lr: 1.0000e-04
# Epoch 27/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0559 - accuracy: 0.9018 - precision: 0.9018 - recall: 0.9018 - auc: 0.9500
# Epoch 27: val_loss improved from 0.05423 to 0.05234, saving model to models\best_model_split_70_20_10.h5
# 117/117 [==============================] - 103s 878ms/step - loss: 0.0559 - accuracy: 0.9018 - precision: 0.9018 - recall: 0.9018 - auc: 0.9500 - val_loss: 0.0523 - val_accuracy: 0.9025 - val_precision: 0.9025 - val_recall: 0.9025 - val_auc: 0.9572 - lr: 1.0000e-04
# Epoch 28/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0551 - accuracy: 0.9018 - precision: 0.9018 - recall: 0.9018 - auc: 0.9523
# Epoch 28: val_loss did not improve from 0.05234
# 117/117 [==============================] - 96s 814ms/step - loss: 0.0551 - accuracy: 0.9018 - precision: 0.9018 - recall: 0.9018 - auc: 0.9523 - val_loss: 0.0544 - val_accuracy: 0.8892 - val_precision: 0.8892 - val_recall: 0.8892 - val_auc: 0.9573 - lr: 1.0000e-04
# Epoch 29/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0547 - accuracy: 0.9041 - precision: 0.9041 - recall: 0.9041 - auc: 0.9524
# Epoch 29: val_loss did not improve from 0.05234
# 117/117 [==============================] - 108s 925ms/step - loss: 0.0547 - accuracy: 0.9041 - precision: 0.9041 - recall: 0.9041 - auc: 0.9524 - val_loss: 0.0538 - val_accuracy: 0.8958 - val_precision: 0.8958 - val_recall: 0.8958 - val_auc: 0.9571 - lr: 1.0000e-04
# Epoch 30/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0544 - accuracy: 0.9045 - precision: 0.9045 - recall: 0.9045 - auc: 0.9532
# Epoch 30: val_loss did not improve from 0.05234
# 117/117 [==============================] - 103s 879ms/step - loss: 0.0544 - accuracy: 0.9045 - precision: 0.9045 - recall: 0.9045 - auc: 0.9532 - val_loss: 0.0566 - val_accuracy: 0.9015 - val_precision: 0.9015 - val_recall: 0.9015 - val_auc: 0.9526 - lr: 1.0000e-04
# Epoch 31/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0535 - accuracy: 0.9039 - precision: 0.9039 - recall: 0.9039 - auc: 0.9547
# Epoch 31: val_loss did not improve from 0.05234
# 117/117 [==============================] - 98s 837ms/step - loss: 0.0535 - accuracy: 0.9039 - precision: 0.9039 - recall: 0.9039 - auc: 0.9547 - val_loss: 0.0532 - val_accuracy: 0.9034 - val_precision: 0.9034 - val_recall: 0.9034 - val_auc: 0.9560 - lr: 1.0000e-04
# Epoch 32/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0532 - accuracy: 0.9039 - precision: 0.9039 - recall: 0.9039 - auc: 0.9558
# Epoch 32: val_loss did not improve from 0.05234
# 117/117 [==============================] - 96s 817ms/step - loss: 0.0532 - accuracy: 0.9039 - precision: 0.9039 - recall: 0.9039 - auc: 0.9558 - val_loss: 0.0524 - val_accuracy: 0.8987 - val_precision: 0.8987 - val_recall: 0.8987 - val_auc: 0.9591 - lr: 1.0000e-04
# Epoch 33/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0540 - accuracy: 0.9023 - precision: 0.9023 - recall: 0.9023 - auc: 0.9544
# Epoch 33: val_loss did not improve from 0.05234
# 117/117 [==============================] - 96s 821ms/step - loss: 0.0540 - accuracy: 0.9023 - precision: 0.9023 - recall: 0.9023 - auc: 0.9544 - val_loss: 0.0528 - val_accuracy: 0.8996 - val_precision: 0.8996 - val_recall: 0.8996 - val_auc: 0.9569 - lr: 1.0000e-04
# Epoch 34/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0532 - accuracy: 0.9050 - precision: 0.9050 - recall: 0.9050 - auc: 0.9554
# Epoch 34: val_loss did not improve from 0.05234
# 117/117 [==============================] - 98s 837ms/step - loss: 0.0532 - accuracy: 0.9050 - precision: 0.9050 - recall: 0.9050 - auc: 0.9554 - val_loss: 0.0525 - val_accuracy: 0.9006 - val_precision: 0.9006 - val_recall: 0.9006 - val_auc: 0.9601 - lr: 1.0000e-04
# Epoch 35/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0519 - accuracy: 0.9053 - precision: 0.9053 - recall: 0.9053 - auc: 0.9581
# Epoch 35: val_loss improved from 0.05234 to 0.05183, saving model to models\best_model_split_70_20_10.h5
# 117/117 [==============================] - 109s 930ms/step - loss: 0.0519 - accuracy: 0.9053 - precision: 0.9053 - recall: 0.9053 - auc: 0.9581 - val_loss: 0.0518 - val_accuracy: 0.8996 - val_precision: 0.8996 - val_recall: 0.8996 - val_auc: 0.9611 - lr: 1.0000e-04
# Epoch 36/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0529 - accuracy: 0.9026 - precision: 0.9026 - recall: 0.9026 - auc: 0.9571
# Epoch 36: val_loss improved from 0.05183 to 0.05145, saving model to models\best_model_split_70_20_10.h5
# 117/117 [==============================] - 104s 884ms/step - loss: 0.0529 - accuracy: 0.9026 - precision: 0.9026 - recall: 0.9026 - auc: 0.9571 - val_loss: 0.0515 - val_accuracy: 0.8977 - val_precision: 0.8977 - val_recall: 0.8977 - val_auc: 0.9610 - lr: 1.0000e-04
# Epoch 37/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0523 - accuracy: 0.9042 - precision: 0.9042 - recall: 0.9042 - auc: 0.9581
# Epoch 37: val_loss improved from 0.05145 to 0.05043, saving model to models\best_model_split_70_20_10.h5
# 117/117 [==============================] - 103s 873ms/step - loss: 0.0523 - accuracy: 0.9042 - precision: 0.9042 - recall: 0.9042 - auc: 0.9581 - val_loss: 0.0504 - val_accuracy: 0.9006 - val_precision: 0.9006 - val_recall: 0.9006 - val_auc: 0.9621 - lr: 1.0000e-04
# Epoch 38/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0516 - accuracy: 0.9074 - precision: 0.9074 - recall: 0.9074 - auc: 0.9589
# Epoch 38: val_loss improved from 0.05043 to 0.05004, saving model to models\best_model_split_70_20_10.h5
# 117/117 [==============================] - 101s 862ms/step - loss: 0.0516 - accuracy: 0.9074 - precision: 0.9074 - recall: 0.9074 - auc: 0.9589 - val_loss: 0.0500 - val_accuracy: 0.9015 - val_precision: 0.9015 - val_recall: 0.9015 - val_auc: 0.9630 - lr: 1.0000e-04
# Epoch 39/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0515 - accuracy: 0.9029 - precision: 0.9029 - recall: 0.9029 - auc: 0.9591
# Epoch 39: val_loss did not improve from 0.05004
# 117/117 [==============================] - 95s 812ms/step - loss: 0.0515 - accuracy: 0.9029 - precision: 0.9029 - recall: 0.9029 - auc: 0.9591 - val_loss: 0.0545 - val_accuracy: 0.8864 - val_precision: 0.8864 - val_recall: 0.8864 - val_auc: 0.9565 - lr: 1.0000e-04
# Epoch 40/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0521 - accuracy: 0.9039 - precision: 0.9039 - recall: 0.9039 - auc: 0.9586
# Epoch 40: val_loss did not improve from 0.05004
# 117/117 [==============================] - 95s 808ms/step - loss: 0.0521 - accuracy: 0.9039 - precision: 0.9039 - recall: 0.9039 - auc: 0.9586 - val_loss: 0.0514 - val_accuracy: 0.9025 - val_precision: 0.9025 - val_recall: 0.9025 - val_auc: 0.9619 - lr: 1.0000e-04
# Epoch 41/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0519 - accuracy: 0.9050 - precision: 0.9050 - recall: 0.9050 - auc: 0.9586
# Epoch 41: val_loss improved from 0.05004 to 0.04986, saving model to models\best_model_split_70_20_10.h5
# 117/117 [==============================] - 95s 806ms/step - loss: 0.0519 - accuracy: 0.9050 - precision: 0.9050 - recall: 0.9050 - auc: 0.9586 - val_loss: 0.0499 - val_accuracy: 0.9025 - val_precision: 0.9025 - val_recall: 0.9025 - val_auc: 0.9629 - lr: 1.0000e-04
# Epoch 42/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0501 - accuracy: 0.9047 - precision: 0.9047 - recall: 0.9047 - auc: 0.9616
# Epoch 42: val_loss did not improve from 0.04986
# 117/117 [==============================] - 96s 816ms/step - loss: 0.0501 - accuracy: 0.9047 - precision: 0.9047 - recall: 0.9047 - auc: 0.9616 - val_loss: 0.0503 - val_accuracy: 0.9034 - val_precision: 0.9034 - val_recall: 0.9034 - val_auc: 0.9636 - lr: 1.0000e-04
# Epoch 43/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0508 - accuracy: 0.9050 - precision: 0.9050 - recall: 0.9050 - auc: 0.9607
# Epoch 43: val_loss improved from 0.04986 to 0.04874, saving model to models\best_model_split_70_20_10.h5
# 117/117 [==============================] - 103s 882ms/step - loss: 0.0508 - accuracy: 0.9050 - precision: 0.9050 - recall: 0.9050 - auc: 0.9607 - val_loss: 0.0487 - val_accuracy: 0.9034 - val_precision: 0.9034 - val_recall: 0.9034 - val_auc: 0.9650 - lr: 1.0000e-04
# Epoch 44/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0515 - accuracy: 0.9058 - precision: 0.9058 - recall: 0.9058 - auc: 0.9593
# Epoch 44: val_loss did not improve from 0.04874
# 117/117 [==============================] - 103s 878ms/step - loss: 0.0515 - accuracy: 0.9058 - precision: 0.9058 - recall: 0.9058 - auc: 0.9593 - val_loss: 0.0591 - val_accuracy: 0.8674 - val_precision: 0.8674 - val_recall: 0.8674 - val_auc: 0.9486 - lr: 1.0000e-04
# Epoch 45/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0508 - accuracy: 0.9090 - precision: 0.9090 - recall: 0.9090 - auc: 0.9607
# Epoch 45: val_loss did not improve from 0.04874
# 117/117 [==============================] - 103s 876ms/step - loss: 0.0508 - accuracy: 0.9090 - precision: 0.9090 - recall: 0.9090 - auc: 0.9607 - val_loss: 0.0500 - val_accuracy: 0.9015 - val_precision: 0.9015 - val_recall: 0.9015 - val_auc: 0.9640 - lr: 1.0000e-04
# Epoch 46/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0507 - accuracy: 0.9064 - precision: 0.9064 - recall: 0.9064 - auc: 0.9605
# Epoch 46: val_loss did not improve from 0.04874
# 117/117 [==============================] - 109s 928ms/step - loss: 0.0507 - accuracy: 0.9064 - precision: 0.9064 - recall: 0.9064 - auc: 0.9605 - val_loss: 0.0498 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9633 - lr: 1.0000e-04
# Epoch 47/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0510 - accuracy: 0.9082 - precision: 0.9082 - recall: 0.9082 - auc: 0.9600
# Epoch 47: val_loss improved from 0.04874 to 0.04765, saving model to models\best_model_split_70_20_10.h5
# 117/117 [==============================] - 96s 814ms/step - loss: 0.0510 - accuracy: 0.9082 - precision: 0.9082 - recall: 0.9082 - auc: 0.9600 - val_loss: 0.0476 - val_accuracy: 0.9072 - val_precision: 0.9072 - val_recall: 0.9072 - val_auc: 0.9664 - lr: 1.0000e-04
# Epoch 48/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0502 - accuracy: 0.9082 - precision: 0.9082 - recall: 0.9082 - auc: 0.9609
# Epoch 48: val_loss did not improve from 0.04765
# 117/117 [==============================] - 95s 808ms/step - loss: 0.0502 - accuracy: 0.9082 - precision: 0.9082 - recall: 0.9082 - auc: 0.9609 - val_loss: 0.0484 - val_accuracy: 0.9044 - val_precision: 0.9044 - val_recall: 0.9044 - val_auc: 0.9652 - lr: 1.0000e-04
# Epoch 49/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0495 - accuracy: 0.9058 - precision: 0.9058 - recall: 0.9058 - auc: 0.9628
# Epoch 49: val_loss did not improve from 0.04765
# 117/117 [==============================] - 97s 827ms/step - loss: 0.0495 - accuracy: 0.9058 - precision: 0.9058 - recall: 0.9058 - auc: 0.9628 - val_loss: 0.0493 - val_accuracy: 0.8987 - val_precision: 0.8987 - val_recall: 0.8987 - val_auc: 0.9650 - lr: 1.0000e-04
# Epoch 50/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0487 - accuracy: 0.9074 - precision: 0.9074 - recall: 0.9074 - auc: 0.9638
# Epoch 50: val_loss did not improve from 0.04765
# 117/117 [==============================] - 96s 816ms/step - loss: 0.0487 - accuracy: 0.9074 - precision: 0.9074 - recall: 0.9074 - auc: 0.9638 - val_loss: 0.0508 - val_accuracy: 0.9044 - val_precision: 0.9044 - val_recall: 0.9044 - val_auc: 0.9626 - lr: 1.0000e-04
# Train history for split_70_20_10 saved as models/history_split_70_20_10.pkl

# %%
import matplotlib.pyplot as plt
import pickle
import os

# load history
history_path = "models/history_split_70_20_10.pkl"  
with open(history_path, 'rb') as f:
    history = pickle.load(f)
    
# Plot training and validation loss and acc
acc = history['accuracy']
val_acc = history['val_accuracy']
loss = history['loss']
val_loss = history['val_loss']

epochs = range(1, len(acc) + 1)

# Define the directory to save the image
save_dir = r"C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_70_20_10"
os.makedirs(save_dir, exist_ok=True)  # Ensure the directory exists

plt.figure(figsize=(12, 4))
# Plot training and validation accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs, acc, label='Training Accuracy')
plt.plot(epochs, val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy', fontsize=16)
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.legend()
accuracy_path = os.path.join(save_dir, 'accuracy_curve_split_70_20_10.png')
plt.savefig(accuracy_path, dpi=600, bbox_inches='tight')
print(f"Accuracy curve saved at: {accuracy_path}")


# Plot training and validation loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.title('Training and Validation Loss', fontsize=16)
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Loss', fontsize=12)
plt.legend()
loss_path = os.path.join(save_dir, 'loss_curve_split_70_20_10.png')
plt.savefig(loss_path, dpi=600, bbox_inches='tight')
print(f"Loss curve saved at: {loss_path}")

plt.show()
# Out:
# Accuracy curve saved at: C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_70_20_10\accuracy_curve_split_70_20_10.png
# Loss curve saved at: C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_70_20_10\loss_curve_split_70_20_10.png

# %%
import matplotlib.pyplot as plt
import pickle

# load history
history_path = 'models/history_split_70_20_10.pkl'  
with open(history_path, 'rb') as f:
    history_dict = pickle.load(f)

def plot_precision_recall(history):
    if 'precision' not in history or 'recall' not in history:
        print("No precision or recall data found in history!")
        return

    save_dir = r"C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_70_20_10"
    os.makedirs(save_dir, exist_ok=True)  
    
    plt.figure(figsize=(12, 4))
    
    # Precision plot
    plt.subplot(1, 2, 1)
    plt.plot(history['precision'], label='Train Precision')
    plt.plot(history['val_precision'], label='Validation Precision')
    plt.title('Precision', fontsize=16)
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Precision', fontsize=12)
    plt.legend()

    # Recall plot
    plt.subplot(1, 2, 2)
    plt.plot(history['recall'], label='Train Recall')
    plt.plot(history['val_recall'], label='Validation Recall')
    plt.title('Recall', fontsize=16)
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Recall', fontsize=12)
    plt.legend()

    plt.tight_layout()

    # Save the figure
    precision_recall_path = os.path.join(save_dir, 'precision_recall_curve_split_70_20_10.png')
    plt.savefig(precision_recall_path, dpi=600, bbox_inches='tight')
    print(f"Precision and Recall curve saved at: {precision_recall_path}")
    
    plt.show()


plot_precision_recall(history_dict)
# Out:
# Precision and Recall curve saved at: C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_70_20_10\precision_recall_curve_split_70_20_10.png

# %%
import matplotlib.pyplot as plt
import pickle

# load history
history_path = 'models/history_split_70_20_10.pkl' 
with open(history_path, 'rb') as f:
    history_dict = pickle.load(f)
    
def plot_auc(history):
    if 'auc' not in history or 'val_auc' not in history:
        print("No AUC data found in history!")
        return
    save_dir = r"C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_70_20_10"
    os.makedirs(save_dir, exist_ok=True) 
    
    plt.figure(figsize=(12, 4))

    # AUC plot
    plt.plot(history['auc'], label='Train AUC')
    plt.plot(history['val_auc'], label='Validation AUC')
    plt.title('AUC', fontsize=16)
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('AUC', fontsize=12)
    plt.legend()

    auc_path = os.path.join(save_dir, 'auc_curve_split_70_20_10.png')
    plt.savefig(auc_path, dpi=600, bbox_inches='tight')
    print(f"AUC curve saved at: {auc_path}")

    plt.show()


plot_auc(history_dict)
# Out:
# AUC curve saved at: C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_70_20_10\auc_curve_split_70_20_10.png

# %%
from tensorflow.keras.models import load_model

# load model and loss function
model = load_model(
    'models/best_model_split_70_20_10.h5',
    custom_objects={'focal_loss_fixed': focal_loss(gamma=2., alpha=0.75)}  
)

# evaluation
test_loss, test_accuracy, test_precision, test_recall, test_auc = model.evaluate(test_generator_70_20_10, verbose=1)

print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Precision: {test_precision}")
print(f"Test Recall: {test_recall}")
print(f"Test AUC: {test_auc}")
# Out:
# 17/17 [==============================] - 14s 425ms/step - loss: 0.0464 - accuracy: 0.9156 - precision: 0.9156 - recall: 0.9156 - auc: 0.9677
# Test Loss: 0.04641364514827728
# Test Accuracy: 0.9155722260475159
# Test Precision: 0.9155722260475159
# Test Recall: 0.9155722260475159
# Test AUC: 0.9676949977874756

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns
import os
import matplotlib.pyplot as plt


save_dir = r"C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_70_20_10"
os.makedirs(save_dir, exist_ok=True)

test_steps = test_generator_70_20_10.samples // test_generator_70_20_10.batch_size  
y_true = []
y_pred = []

# get prediction result
for _ in range(test_steps):
    x, y = test_generator_70_20_10.next()
    predictions = model.predict(x)
    
    # get true label
    y_true.extend(np.argmax(y, axis=1)) 
    # get prediction label
    y_pred.extend(np.argmax(predictions, axis=1))


# Confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Calculate sensitivity (Recall) and specificity
TP = cm[1, 1] 
TN = cm[0, 0]  
FP = cm[0, 1]  
FN = cm[1, 0]  

sensitivity = TP / float(TP + FN)
specificity = TN / float(TN + FP)

print(f'Sensitivity (Recall): {sensitivity}')
print(f'Specificity: {specificity}')

# Plot the confusion matrix
plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No Defect', 'Defect'], yticklabels=['No Defect', 'Defect'])
plt.title('Confusion Matrix of split_70_20_10', fontsize=14)
plt.xlabel('Predicted', fontsize=12)
plt.ylabel('True', fontsize=12)

# Save the confusion matrix plot
confusion_matrix_path = os.path.join(save_dir, 'confusion_matrix_split_70_20_10.png')
plt.savefig(confusion_matrix_path, dpi=600, bbox_inches='tight')

# Print the saved path
print(f"Confusion matrix saved at: {confusion_matrix_path}")

# Show the plot
plt.show()
# Out:
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 78ms/step
# Sensitivity (Recall): 0.9977628635346756
# Specificity: 0.35185185185185186
# Confusion matrix saved at: C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_70_20_10\confusion_matrix_split_70_20_10.png

# %%
from sklearn.metrics import f1_score
import numpy as np

test_steps = test_generator_70_20_10.samples // test_generator_70_20_10.batch_size
y_true = []
y_pred = []

for _ in range(test_steps):
    x, y = test_generator_70_20_10.next()
    predictions = model.predict(x)
    y_true.extend(np.argmax(y, axis=1))              
    y_pred.extend(np.argmax(predictions, axis=1))   

f1 = f1_score(y_true, y_pred, average='binary') 
print(f'F1 Score: {f1:.4f}')
# Out:
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 84ms/step
# F1 Score: 0.9533

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt
import numpy as np
import os

save_dir = r"C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_70_20_10"
os.makedirs(save_dir, exist_ok=True)

test_steps = test_generator_70_20_10.samples // test_generator_70_20_10.batch_size

y_true = []
y_scores = []

for _ in range(test_steps):
    x_batch, y_batch = test_generator_70_20_10.next()
    preds = model.predict(x_batch)

    y_true.extend(np.argmax(y_batch, axis=1))
    
    y_scores.extend(preds[:, 1])

precision, recall, thresholds = precision_recall_curve(y_true, y_scores)

plt.figure(figsize=(6, 4))
plt.plot(recall, precision, label='Precision-Recall Curve', color='darkorange')
plt.xlabel('Recall', fontsize=12)
plt.ylabel('Precision', fontsize=12)
plt.title('Precision-Recall Curve (Defect Detection)', fontsize=16)
plt.legend(loc="lower left")
plt.grid(True)

# Corrected variable name
precision_recall_curve_path = os.path.join(save_dir, 'precision-recall_curve_split_70_20_10.png')
plt.savefig(precision_recall_curve_path, dpi=600, bbox_inches='tight')
print(f"Precision_Recall Curve saved at: {precision_recall_curve_path}")

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 77ms/step
# Precision_Recall Curve saved at: C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_70_20_10\precision-recall_curve_split_70_20_10.png

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
import numpy as np

save_dir = r"C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_70_20_10"
os.makedirs(save_dir, exist_ok=True)

test_steps = test_generator_70_20_10.samples // test_generator_70_20_10.batch_size

y_true = []
y_scores = []

for _ in range(test_steps):
    x_batch, y_batch = test_generator_70_20_10.next()
    preds = model.predict(x_batch)

    y_true.extend(np.argmax(y_batch, axis=1))

    y_scores.extend(preds[:, 1])

# calculate ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)

# ROC curve
plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC Curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random Guessing')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=12)
plt.ylabel('True Positive Rate', fontsize=12)
plt.title('ROC Curve - Defect Detection', fontsize=16)
plt.legend(loc="lower right")
plt.grid(True)

ROC_Curve_path = os.path.join(save_dir, 'roc_curve_split_70_20_10.png')
plt.savefig(confusion_matrix_path, dpi=600, bbox_inches='tight')
print(f"ROC Curve saved at: {ROC_Curve_path}")

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 84ms/step
# ROC Curve saved at: C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_70_20_10\roc_curve_split_70_20_10.png

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import cv2
import os

def get_img_array(img_path, size=(128, 128)):
    img = image.load_img(img_path, target_size=size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    return img_array / 255.0

def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=1):
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        class_channel = predictions[:, pred_index]
    grads = tape.gradient(class_channel, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
    conv_outputs = conv_outputs[0]
    heatmap = conv_outputs @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    heatmap = np.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

def save_gradcam_only(heatmap, save_path, size=(128, 128), colormap=cv2.COLORMAP_JET):
    heatmap = cv2.resize(heatmap, size)
    heatmap = np.uint8(255 * heatmap)
    heatmap_color = cv2.applyColorMap(heatmap, colormap)
    cv2.imwrite(save_path, heatmap_color)

def save_and_display_gradcam(img_path, heatmap, cam_path, alpha=0.4, size=(128, 128)):
    img = cv2.imread(img_path)
    if img is None:
        raise FileNotFoundError(f"Image not found at: {img_path}")
    img = cv2.resize(img, size)
    
    heatmap_resized = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
    heatmap_resized = np.uint8(255 * heatmap_resized)
    heatmap_color = cv2.applyColorMap(heatmap_resized, cv2.COLORMAP_JET)
    
    superimposed_img = cv2.addWeighted(img, 1 - alpha, heatmap_color, alpha, 0)
    cv2.imwrite(cam_path, superimposed_img)

# Load model
model = tf.keras.models.load_model(
    'models/best_model_split_70_20_10.h5', 
    custom_objects={'focal_loss_fixed': focal_loss(gamma=2., alpha=0.75)}
)

# Target image path
img_path = r"C:\Users\xiaog\Desktop\Project\Datasets\dataset\split_70_20_10\train\images\train_1349.jpg"
img_array = get_img_array(img_path)

# Get predictions for the image
predictions = model.predict(img_array)
print(f"Predicted probabilities: {predictions}")

# Now, based on your description, "1" is defective (with defect), and "0" is non-defective (without defect)
pred_index = 1 if predictions[0][1] > predictions[0][0] else 0

# Dynamically get the predicted class name
class_names = ['non_defective', 'defective']  # Define your class names
predicted_class = class_names[pred_index]  # Use pred_index to get the predicted class name

print(f"Predicted class: {predicted_class}")

# Generate the Grad-CAM heatmap for the correct class
heatmap = make_gradcam_heatmap(img_array, model, last_conv_layer_name='concatenate_5', pred_index=pred_index)


# Save Grad-CAM heatmap (not overlaid)
img_name = os.path.basename(img_path).split('.')[0]
heatmap_path = f"C:/Users/xiaog/Desktop/Project/Datasets/dataset/Performance/XAI/Grad-CAM/heatmap_{img_name}_{predicted_class}.jpg"
save_gradcam_only(heatmap, heatmap_path)

# Save Grad-CAM overlay (superimposed image)
cam_path = f"C:/Users/xiaog/Desktop/Project/Datasets/dataset/Performance/XAI/Grad-CAM/cam_{img_name}_{predicted_class}.jpg"
save_and_display_gradcam(img_path, heatmap, cam_path)

# Display all three images side by side and save as one image
original_img = cv2.imread(img_path)
original_img = cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB)
original_img = cv2.resize(original_img, (128, 128))

gradcam_img = cv2.imread(cam_path)
gradcam_img = cv2.cvtColor(gradcam_img, cv2.COLOR_BGR2RGB)

heatmap_img = cv2.imread(heatmap_path)
heatmap_img = cv2.cvtColor(heatmap_img, cv2.COLOR_BGR2RGB)

# Create a single figure to display all three images side by side
fig, axes = plt.subplots(1, 3, figsize=(12, 4), dpi=600)

axes[0].imshow(original_img)
axes[0].set_title("Original Image", fontsize=14)
axes[0].axis("off")

axes[1].imshow(heatmap_img)
axes[1].set_title(f"Grad-CAM Heatmap ({predicted_class})", fontsize=14)
axes[1].axis("off")

axes[2].imshow(gradcam_img)
axes[2].set_title(f"Grad-CAM Overlay ({predicted_class})", fontsize=14)
axes[2].axis("off")

# Adjust layout to avoid title clipping
plt.subplots_adjust(wspace=0.2)

# Save the combined image
combined_image_path = f"C:/Users/xiaog/Desktop/Project/Datasets/dataset/Performance/XAI/Grad-CAM/combined_{img_name}_{predicted_class}.jpg"
fig.savefig(combined_image_path, dpi=600)

# Display the combined image
plt.show()

print(f"Combined Grad-CAM image saved to: {combined_image_path}")
# Out:
# 1/1 [==============================] - 2s 2s/step
# Predicted probabilities: [[0.13269517 0.86730486]]
# Predicted class: defective
# Combined Grad-CAM image saved to: C:/Users/xiaog/Desktop/Project/Datasets/dataset/Performance/XAI/Grad-CAM/combined_train_1349_defective.jpg
