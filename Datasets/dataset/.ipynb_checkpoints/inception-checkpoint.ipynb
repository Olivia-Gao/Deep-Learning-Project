# %%
import os
import pandas as pd
import xml.etree.ElementTree as ET

# data path
train_dir = r'C:\Users\xiaog\Desktop\Project\Datasets\dataset\split_70_20_10\train'
valid_dir = r'C:\Users\xiaog\Desktop\Project\Datasets\dataset\split_70_20_10\valid'
test_dir = r'C:\Users\xiaog\Desktop\Project\Datasets\dataset\split_70_20_10\test'

# %%
# get label
def get_label_from_xml(xml_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()
    objects = root.findall('object')

    # if exist "thermal_defect", return 1
    for obj in objects:
        if obj.find('name').text == 'thermal_defect':
            return "1"  

    return "0" 

# count defects
def count_defects_in_directory(data_dir):
    with_defect = 0
    without_defect = 0
    
    for root, _, files in os.walk(data_dir):
        for file in files:
            if file.endswith('.xml'):
                xml_path = os.path.join(root, file)
                img_path = os.path.join(root.replace('annotations', 'images'), file.replace('.xml', '.jpg'))

                if os.path.exists(img_path):  
                    label = get_label_from_xml(xml_path)  
                    if label == "1":
                        with_defect += 1
                    else:
                        without_defect += 1
    
    return with_defect, without_defect

def create_dataframe(data_dir):
    data = []
    
    for root, _, files in os.walk(data_dir):
        for file in files:
            if file.endswith('.xml'):
                xml_path = os.path.join(root, file)
                img_path = os.path.join(root.replace('annotations', 'images'), file.replace('.xml', '.jpg'))

                if os.path.exists(img_path):  
                    label = get_label_from_xml(xml_path) 
                    data.append([img_path, label])
    
    return pd.DataFrame(data, columns=['filepath', 'label'])

train_df = create_dataframe(train_dir)
valid_df = create_dataframe(valid_dir)
test_df = create_dataframe(test_dir)

print(f"Train set: {len(train_df)} images")
print(f"Valid set: {len(valid_df)} images")
print(f"Test set: {len(test_df)} images")

train_with_defect, train_without_defect = count_defects_in_directory(train_dir)
valid_with_defect, valid_without_defect = count_defects_in_directory(valid_dir)
test_with_defect, test_without_defect = count_defects_in_directory(test_dir)

print(f"Train set - defect: {train_with_defect}, no_defect: {train_without_defect}")
print(f"Valid set - defect: {valid_with_defect}, no_defect: {valid_without_defect}")
print(f"Test set - defect: {test_with_defect}, no_defect: {test_without_defect}")
# Out:
# Train set: 3748 images
# Valid set: 1071 images
# Test set: 533 images
# Train set - defect: 3321, no_defect: 427
# Valid set - defect: 942, no_defect: 129
# Test set - defect: 470, no_defect: 63

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

train_datagen = ImageDataGenerator(
    rescale=1./255,  
    rotation_range=30,  
    width_shift_range=0.2,  
    height_shift_range=0.2,  
    shear_range=0.2, 
    zoom_range=0.2, 
    horizontal_flip=True 
)

valid_test_datagen = ImageDataGenerator(rescale=1./255)

# train generator
train_generator_70_20_10 = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col="filepath",
    y_col="label",
    target_size=(128, 128),
    batch_size=32,
    class_mode="categorical"  
)

# valid generator
valid_generator_70_20_10 = valid_test_datagen.flow_from_dataframe(
    dataframe=valid_df,
    x_col="filepath",
    y_col="label",
    target_size=(128, 128),
    batch_size=32,
    class_mode="categorical"
)

# test generator
test_generator_70_20_10 = valid_test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col="filepath",
    y_col="label",
    target_size=(128, 128),
    batch_size=32,
    class_mode="categorical",
    shuffle=False  
)

print(f"Train generator samples: {train_generator_70_20_10.samples}")
print(f"Valid generator samples: {valid_generator_70_20_10.samples}")
print(f"Test generator samples: {test_generator_70_20_10.samples}")
# Out:
# Found 3748 validated image filenames belonging to 2 classes.
# Found 1071 validated image filenames belonging to 2 classes.
# Found 533 validated image filenames belonging to 2 classes.
# Train generator samples: 3748
# Valid generator samples: 1071
# Test generator samples: 533

# %%
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model

def inception_module(x, filters):
    # 1x1 Conv
    conv1x1 = Conv2D(filters, (1,1), padding='same', activation='relu')(x)
    
    # 3x3 Conv
    conv3x3 = Conv2D(filters, (3,3), padding='same', activation='relu')(x)
    
    # 5x5 Conv
    conv5x5 = Conv2D(filters, (5,5), padding='same', activation='relu')(x)
    
    pool = MaxPooling2D((3,3), strides=(1,1), padding='same')(x)
    pool = Conv2D(filters, (1,1), padding='same', activation='relu')(pool)
    
    merged = concatenate([conv1x1, conv3x3, conv5x5, pool], axis=-1)
    return merged

def build_inception_model(input_shape=(128, 128, 3), num_classes=2):
    inputs = Input(shape=input_shape)
    x = inception_module(inputs, 32)
    x = MaxPooling2D(2)(x)
    x = inception_module(x, 64)
    x = MaxPooling2D(2)(x)
    x = inception_module(x, 128)
    x = GlobalAveragePooling2D()(x)  # Global average pooling for feature reduction

    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs=inputs, outputs=outputs)
    return model

# Build the modified model
inception_model = build_inception_model(input_shape=(128, 128, 3), num_classes=2)

# Print the model summary
inception_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 3)  0           ['input_1[0][0]']
#
#  conv2d (Conv2D)                (None, 128, 128, 32  128         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 32  896         ['input_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 32  2432        ['input_1[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 32  128         ['max_pooling2d[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 128, 128, 12  0           ['conv2d[0][0]',
#                                 8)                                'conv2d_1[0][0]',
#                                                                   'conv2d_2[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0          ['concatenate[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 128)  0          ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 64)   8256        ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 64)   73792       ['max_pooling2d_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 64)   204864      ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 64)   8256        ['max_pooling2d_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 256)  0           ['conv2d_4[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_6[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 256)  0          ['concatenate_1[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 32, 32, 256)  0          ['max_pooling2d_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 128)  32896       ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 128)  295040      ['max_pooling2d_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 128)  819328      ['max_pooling2d_3[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 128)  32896       ['max_pooling2d_4[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 32, 32, 512)  0           ['conv2d_8[0][0]',
#                                                                   'conv2d_9[0][0]',
#                                                                   'conv2d_10[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['concatenate_2[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            1026        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 1,479,938
# Trainable params: 1,479,938
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Precision, Recall

def focal_loss(gamma=2., alpha=0.75):
    """
    Focal Loss implementation for binary classification.

    Parameters:
        gamma (float): Focusing parameter. Default is 2.
        alpha (float): Weighting factor for class imbalance. Default is 0.75 for better focusing on less frequent class.

    Returns:
        loss (function): Focal loss function.
    """

    def focal_loss_fixed(y_true, y_pred):
        # Clip predictions to avoid log(0)
        y_pred = K.clip(y_pred, K.epsilon(), 1. - K.epsilon())

        # Calculate cross entropy
        cross_entropy = -y_true * K.log(y_pred)

        # Calculate modulating factor (1 - p_t) ^ gamma
        modulating_factor = K.pow(1 - y_pred, gamma)

        # Calculate the focal loss
        loss = alpha * modulating_factor * cross_entropy

        return K.sum(loss, axis=-1)

    return focal_loss_fixed

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau


def compile_model(model, split_name="split_70_20_10"):
    model.compile(
        optimizer=Adam(learning_rate=1e-4),
        loss=focal_loss(gamma=2., alpha=0.75),
        metrics=[
            'accuracy', 
            Precision(name='precision'), 
            Recall(name='recall'), 
            'AUC']
    )

    callbacks = [
        EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True),
        ModelCheckpoint(
            filepath=f'models/inception_model_{split_name}.h5',
            monitor='val_loss',
            save_best_only=True,
            mode='min',
            verbose=1
        ),
        ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=10, min_lr=1e-6)
    ]

    return callbacks

# %%
import pickle
import numpy as np 

def train_and_save_history(train_generator, valid_generator, split_name="split_70_20_10", epochs=50, batch_size=32):
    steps_per_epoch = train_generator.samples // batch_size
    validation_steps = valid_generator.samples // batch_size

   # compile model
    model = build_inception_model() 

    callbacks = compile_model(model, split_name)

    history = model.fit(
        train_generator,
        steps_per_epoch=steps_per_epoch,
        validation_data=valid_generator,
        validation_steps=validation_steps,
        epochs=epochs,
        callbacks=callbacks
    )

    # save history
    history_path = f"models/inception_model_history_{split_name}.pkl"
    with open(history_path, 'wb') as f:  
        pickle.dump(history.history, f)

    print(f"Inception_model_history for {split_name} saved as {history_path}")


# train `split_70_20_10` and save history
train_and_save_history(train_generator_70_20_10, valid_generator_70_20_10, split_name="split_70_20_10")
# Out:
# Epoch 1/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0703 - accuracy: 0.8802 - precision: 0.8802 - recall: 0.8802 - auc: 0.9117
# Epoch 1: val_loss improved from inf to 0.06597, saving model to models\inception_model_split_70_20_10.h5
# 117/117 [==============================] - 88s 671ms/step - loss: 0.0703 - accuracy: 0.8802 - precision: 0.8802 - recall: 0.8802 - auc: 0.9117 - val_loss: 0.0660 - val_accuracy: 0.8797 - val_precision: 0.8797 - val_recall: 0.8797 - val_auc: 0.9358 - lr: 1.0000e-04
# Epoch 2/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0651 - accuracy: 0.8860 - precision: 0.8860 - recall: 0.8860 - auc: 0.9316
# Epoch 2: val_loss improved from 0.06597 to 0.06276, saving model to models\inception_model_split_70_20_10.h5
# 117/117 [==============================] - 95s 812ms/step - loss: 0.0651 - accuracy: 0.8860 - precision: 0.8860 - recall: 0.8860 - auc: 0.9316 - val_loss: 0.0628 - val_accuracy: 0.8788 - val_precision: 0.8788 - val_recall: 0.8788 - val_auc: 0.9386 - lr: 1.0000e-04
# Epoch 3/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0623 - accuracy: 0.8870 - precision: 0.8870 - recall: 0.8870 - auc: 0.9369
# Epoch 3: val_loss improved from 0.06276 to 0.06050, saving model to models\inception_model_split_70_20_10.h5
# 117/117 [==============================] - 94s 804ms/step - loss: 0.0623 - accuracy: 0.8870 - precision: 0.8870 - recall: 0.8870 - auc: 0.9369 - val_loss: 0.0605 - val_accuracy: 0.8807 - val_precision: 0.8807 - val_recall: 0.8807 - val_auc: 0.9423 - lr: 1.0000e-04
# Epoch 4/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0606 - accuracy: 0.8889 - precision: 0.8889 - recall: 0.8889 - auc: 0.9400
# Epoch 4: val_loss improved from 0.06050 to 0.05986, saving model to models\inception_model_split_70_20_10.h5
# 117/117 [==============================] - 97s 822ms/step - loss: 0.0606 - accuracy: 0.8889 - precision: 0.8889 - recall: 0.8889 - auc: 0.9400 - val_loss: 0.0599 - val_accuracy: 0.8949 - val_precision: 0.8949 - val_recall: 0.8949 - val_auc: 0.9429 - lr: 1.0000e-04
# Epoch 5/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0587 - accuracy: 0.8905 - precision: 0.8905 - recall: 0.8905 - auc: 0.9434
# Epoch 5: val_loss improved from 0.05986 to 0.05920, saving model to models\inception_model_split_70_20_10.h5
# 117/117 [==============================] - 96s 819ms/step - loss: 0.0587 - accuracy: 0.8905 - precision: 0.8905 - recall: 0.8905 - auc: 0.9434 - val_loss: 0.0592 - val_accuracy: 0.8996 - val_precision: 0.8996 - val_recall: 0.8996 - val_auc: 0.9443 - lr: 1.0000e-04
# Epoch 6/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0576 - accuracy: 0.8983 - precision: 0.8983 - recall: 0.8983 - auc: 0.9455
# Epoch 6: val_loss improved from 0.05920 to 0.05867, saving model to models\inception_model_split_70_20_10.h5
# 117/117 [==============================] - 95s 807ms/step - loss: 0.0576 - accuracy: 0.8983 - precision: 0.8983 - recall: 0.8983 - auc: 0.9455 - val_loss: 0.0587 - val_accuracy: 0.8977 - val_precision: 0.8977 - val_recall: 0.8977 - val_auc: 0.9474 - lr: 1.0000e-04
# Epoch 7/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0571 - accuracy: 0.8977 - precision: 0.8977 - recall: 0.8977 - auc: 0.9469
# Epoch 7: val_loss improved from 0.05867 to 0.05623, saving model to models\inception_model_split_70_20_10.h5
# 117/117 [==============================] - 97s 828ms/step - loss: 0.0571 - accuracy: 0.8977 - precision: 0.8977 - recall: 0.8977 - auc: 0.9469 - val_loss: 0.0562 - val_accuracy: 0.9015 - val_precision: 0.9015 - val_recall: 0.9015 - val_auc: 0.9497 - lr: 1.0000e-04
# Epoch 8/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0561 - accuracy: 0.8999 - precision: 0.8999 - recall: 0.8999 - auc: 0.9484
# Epoch 8: val_loss did not improve from 0.05623
# 117/117 [==============================] - 99s 845ms/step - loss: 0.0561 - accuracy: 0.8999 - precision: 0.8999 - recall: 0.8999 - auc: 0.9484 - val_loss: 0.0579 - val_accuracy: 0.8930 - val_precision: 0.8930 - val_recall: 0.8930 - val_auc: 0.9476 - lr: 1.0000e-04
# Epoch 9/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0545 - accuracy: 0.9010 - precision: 0.9010 - recall: 0.9010 - auc: 0.9518
# Epoch 9: val_loss did not improve from 0.05623
# 117/117 [==============================] - 99s 846ms/step - loss: 0.0545 - accuracy: 0.9010 - precision: 0.9010 - recall: 0.9010 - auc: 0.9518 - val_loss: 0.0570 - val_accuracy: 0.8939 - val_precision: 0.8939 - val_recall: 0.8939 - val_auc: 0.9498 - lr: 1.0000e-04
# Epoch 10/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0547 - accuracy: 0.8994 - precision: 0.8994 - recall: 0.8994 - auc: 0.9522
# Epoch 10: val_loss improved from 0.05623 to 0.05516, saving model to models\inception_model_split_70_20_10.h5
# 117/117 [==============================] - 101s 857ms/step - loss: 0.0547 - accuracy: 0.8994 - precision: 0.8994 - recall: 0.8994 - auc: 0.9522 - val_loss: 0.0552 - val_accuracy: 0.8977 - val_precision: 0.8977 - val_recall: 0.8977 - val_auc: 0.9532 - lr: 1.0000e-04
# Epoch 11/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0545 - accuracy: 0.9037 - precision: 0.9037 - recall: 0.9037 - auc: 0.9513
# Epoch 11: val_loss did not improve from 0.05516
# 117/117 [==============================] - 105s 891ms/step - loss: 0.0545 - accuracy: 0.9037 - precision: 0.9037 - recall: 0.9037 - auc: 0.9513 - val_loss: 0.0569 - val_accuracy: 0.9006 - val_precision: 0.9006 - val_recall: 0.9006 - val_auc: 0.9526 - lr: 1.0000e-04
# Epoch 12/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0545 - accuracy: 0.9029 - precision: 0.9029 - recall: 0.9029 - auc: 0.9520
# Epoch 12: val_loss did not improve from 0.05516
# 117/117 [==============================] - 101s 860ms/step - loss: 0.0545 - accuracy: 0.9029 - precision: 0.9029 - recall: 0.9029 - auc: 0.9520 - val_loss: 0.0566 - val_accuracy: 0.9006 - val_precision: 0.9006 - val_recall: 0.9006 - val_auc: 0.9525 - lr: 1.0000e-04
# Epoch 13/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0538 - accuracy: 0.9034 - precision: 0.9034 - recall: 0.9034 - auc: 0.9531
# Epoch 13: val_loss did not improve from 0.05516
# 117/117 [==============================] - 101s 859ms/step - loss: 0.0538 - accuracy: 0.9034 - precision: 0.9034 - recall: 0.9034 - auc: 0.9531 - val_loss: 0.0555 - val_accuracy: 0.8996 - val_precision: 0.8996 - val_recall: 0.8996 - val_auc: 0.9544 - lr: 1.0000e-04
# Epoch 14/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0532 - accuracy: 0.9045 - precision: 0.9045 - recall: 0.9045 - auc: 0.9543
# Epoch 14: val_loss improved from 0.05516 to 0.05506, saving model to models\inception_model_split_70_20_10.h5
# 117/117 [==============================] - 101s 866ms/step - loss: 0.0532 - accuracy: 0.9045 - precision: 0.9045 - recall: 0.9045 - auc: 0.9543 - val_loss: 0.0551 - val_accuracy: 0.8987 - val_precision: 0.8987 - val_recall: 0.8987 - val_auc: 0.9558 - lr: 1.0000e-04
# Epoch 15/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0527 - accuracy: 0.9050 - precision: 0.9050 - recall: 0.9050 - auc: 0.9563
# Epoch 15: val_loss improved from 0.05506 to 0.05274, saving model to models\inception_model_split_70_20_10.h5
# 117/117 [==============================] - 107s 909ms/step - loss: 0.0527 - accuracy: 0.9050 - precision: 0.9050 - recall: 0.9050 - auc: 0.9563 - val_loss: 0.0527 - val_accuracy: 0.9006 - val_precision: 0.9006 - val_recall: 0.9006 - val_auc: 0.9578 - lr: 1.0000e-04
# Epoch 16/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0527 - accuracy: 0.9042 - precision: 0.9042 - recall: 0.9042 - auc: 0.9561
# Epoch 16: val_loss did not improve from 0.05274
# 117/117 [==============================] - 101s 859ms/step - loss: 0.0527 - accuracy: 0.9042 - precision: 0.9042 - recall: 0.9042 - auc: 0.9561 - val_loss: 0.0545 - val_accuracy: 0.8996 - val_precision: 0.8996 - val_recall: 0.8996 - val_auc: 0.9562 - lr: 1.0000e-04
# Epoch 17/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0518 - accuracy: 0.9050 - precision: 0.9050 - recall: 0.9050 - auc: 0.9567
# Epoch 17: val_loss did not improve from 0.05274
# 117/117 [==============================] - 102s 871ms/step - loss: 0.0518 - accuracy: 0.9050 - precision: 0.9050 - recall: 0.9050 - auc: 0.9567 - val_loss: 0.0543 - val_accuracy: 0.8996 - val_precision: 0.8996 - val_recall: 0.8996 - val_auc: 0.9582 - lr: 1.0000e-04
# Epoch 18/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0525 - accuracy: 0.9018 - precision: 0.9018 - recall: 0.9018 - auc: 0.9556
# Epoch 18: val_loss did not improve from 0.05274
# 117/117 [==============================] - 101s 862ms/step - loss: 0.0525 - accuracy: 0.9018 - precision: 0.9018 - recall: 0.9018 - auc: 0.9556 - val_loss: 0.0592 - val_accuracy: 0.8987 - val_precision: 0.8987 - val_recall: 0.8987 - val_auc: 0.9533 - lr: 1.0000e-04
# Epoch 19/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0515 - accuracy: 0.9037 - precision: 0.9037 - recall: 0.9037 - auc: 0.9584
# Epoch 19: val_loss did not improve from 0.05274
# 117/117 [==============================] - 99s 847ms/step - loss: 0.0515 - accuracy: 0.9037 - precision: 0.9037 - recall: 0.9037 - auc: 0.9584 - val_loss: 0.0548 - val_accuracy: 0.8977 - val_precision: 0.8977 - val_recall: 0.8977 - val_auc: 0.9553 - lr: 1.0000e-04
# Epoch 20/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0514 - accuracy: 0.9042 - precision: 0.9042 - recall: 0.9042 - auc: 0.9586
# Epoch 20: val_loss improved from 0.05274 to 0.05245, saving model to models\inception_model_split_70_20_10.h5
# 117/117 [==============================] - 101s 865ms/step - loss: 0.0514 - accuracy: 0.9042 - precision: 0.9042 - recall: 0.9042 - auc: 0.9586 - val_loss: 0.0525 - val_accuracy: 0.9015 - val_precision: 0.9015 - val_recall: 0.9015 - val_auc: 0.9594 - lr: 1.0000e-04
# Epoch 21/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0517 - accuracy: 0.9047 - precision: 0.9047 - recall: 0.9047 - auc: 0.9583
# Epoch 21: val_loss did not improve from 0.05245
# 117/117 [==============================] - 101s 861ms/step - loss: 0.0517 - accuracy: 0.9047 - precision: 0.9047 - recall: 0.9047 - auc: 0.9583 - val_loss: 0.0545 - val_accuracy: 0.8968 - val_precision: 0.8968 - val_recall: 0.8968 - val_auc: 0.9567 - lr: 1.0000e-04
# Epoch 22/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0511 - accuracy: 0.9053 - precision: 0.9053 - recall: 0.9053 - auc: 0.9595
# Epoch 22: val_loss did not improve from 0.05245
# 117/117 [==============================] - 97s 823ms/step - loss: 0.0511 - accuracy: 0.9053 - precision: 0.9053 - recall: 0.9053 - auc: 0.9595 - val_loss: 0.0565 - val_accuracy: 0.8920 - val_precision: 0.8920 - val_recall: 0.8920 - val_auc: 0.9537 - lr: 1.0000e-04
# Epoch 23/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0515 - accuracy: 0.9042 - precision: 0.9042 - recall: 0.9042 - auc: 0.9585
# Epoch 23: val_loss did not improve from 0.05245
# 117/117 [==============================] - 95s 807ms/step - loss: 0.0515 - accuracy: 0.9042 - precision: 0.9042 - recall: 0.9042 - auc: 0.9585 - val_loss: 0.0536 - val_accuracy: 0.8987 - val_precision: 0.8987 - val_recall: 0.8987 - val_auc: 0.9572 - lr: 1.0000e-04
# Epoch 24/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0518 - accuracy: 0.9039 - precision: 0.9039 - recall: 0.9039 - auc: 0.9576
# Epoch 24: val_loss did not improve from 0.05245
# 117/117 [==============================] - 95s 810ms/step - loss: 0.0518 - accuracy: 0.9039 - precision: 0.9039 - recall: 0.9039 - auc: 0.9576 - val_loss: 0.0602 - val_accuracy: 0.8722 - val_precision: 0.8722 - val_recall: 0.8722 - val_auc: 0.9468 - lr: 1.0000e-04
# Epoch 25/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0509 - accuracy: 0.9058 - precision: 0.9058 - recall: 0.9058 - auc: 0.9591
# Epoch 25: val_loss improved from 0.05245 to 0.05130, saving model to models\inception_model_split_70_20_10.h5
# 117/117 [==============================] - 95s 813ms/step - loss: 0.0509 - accuracy: 0.9058 - precision: 0.9058 - recall: 0.9058 - auc: 0.9591 - val_loss: 0.0513 - val_accuracy: 0.8996 - val_precision: 0.8996 - val_recall: 0.8996 - val_auc: 0.9621 - lr: 1.0000e-04
# Epoch 26/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0526 - accuracy: 0.9045 - precision: 0.9045 - recall: 0.9045 - auc: 0.9561
# Epoch 26: val_loss did not improve from 0.05130
# 117/117 [==============================] - 96s 814ms/step - loss: 0.0526 - accuracy: 0.9045 - precision: 0.9045 - recall: 0.9045 - auc: 0.9561 - val_loss: 0.0537 - val_accuracy: 0.9006 - val_precision: 0.9006 - val_recall: 0.9006 - val_auc: 0.9578 - lr: 1.0000e-04
# Epoch 27/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0511 - accuracy: 0.9050 - precision: 0.9050 - recall: 0.9050 - auc: 0.9590
# Epoch 27: val_loss improved from 0.05130 to 0.05029, saving model to models\inception_model_split_70_20_10.h5
# 117/117 [==============================] - 95s 812ms/step - loss: 0.0511 - accuracy: 0.9050 - precision: 0.9050 - recall: 0.9050 - auc: 0.9590 - val_loss: 0.0503 - val_accuracy: 0.8996 - val_precision: 0.8996 - val_recall: 0.8996 - val_auc: 0.9619 - lr: 1.0000e-04
# Epoch 28/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0507 - accuracy: 0.9045 - precision: 0.9045 - recall: 0.9045 - auc: 0.9596
# Epoch 28: val_loss did not improve from 0.05029
# 117/117 [==============================] - 101s 857ms/step - loss: 0.0507 - accuracy: 0.9045 - precision: 0.9045 - recall: 0.9045 - auc: 0.9596 - val_loss: 0.0526 - val_accuracy: 0.9015 - val_precision: 0.9015 - val_recall: 0.9015 - val_auc: 0.9592 - lr: 1.0000e-04
# Epoch 29/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0495 - accuracy: 0.9066 - precision: 0.9066 - recall: 0.9066 - auc: 0.9620
# Epoch 29: val_loss did not improve from 0.05029
# 117/117 [==============================] - 101s 864ms/step - loss: 0.0495 - accuracy: 0.9066 - precision: 0.9066 - recall: 0.9066 - auc: 0.9620 - val_loss: 0.0524 - val_accuracy: 0.8977 - val_precision: 0.8977 - val_recall: 0.8977 - val_auc: 0.9603 - lr: 1.0000e-04
# Epoch 30/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0500 - accuracy: 0.9053 - precision: 0.9053 - recall: 0.9053 - auc: 0.9610
# Epoch 30: val_loss did not improve from 0.05029
# 117/117 [==============================] - 96s 814ms/step - loss: 0.0500 - accuracy: 0.9053 - precision: 0.9053 - recall: 0.9053 - auc: 0.9610 - val_loss: 0.0523 - val_accuracy: 0.8987 - val_precision: 0.8987 - val_recall: 0.8987 - val_auc: 0.9617 - lr: 1.0000e-04
# Epoch 31/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0498 - accuracy: 0.9053 - precision: 0.9053 - recall: 0.9053 - auc: 0.9617
# Epoch 31: val_loss did not improve from 0.05029
# 117/117 [==============================] - 95s 813ms/step - loss: 0.0498 - accuracy: 0.9053 - precision: 0.9053 - recall: 0.9053 - auc: 0.9617 - val_loss: 0.0536 - val_accuracy: 0.8996 - val_precision: 0.8996 - val_recall: 0.8996 - val_auc: 0.9600 - lr: 1.0000e-04
# Epoch 32/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0503 - accuracy: 0.9053 - precision: 0.9053 - recall: 0.9053 - auc: 0.9609
# Epoch 32: val_loss did not improve from 0.05029
# 117/117 [==============================] - 95s 808ms/step - loss: 0.0503 - accuracy: 0.9053 - precision: 0.9053 - recall: 0.9053 - auc: 0.9609 - val_loss: 0.0523 - val_accuracy: 0.8977 - val_precision: 0.8977 - val_recall: 0.8977 - val_auc: 0.9621 - lr: 1.0000e-04
# Epoch 33/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0533 - accuracy: 0.8967 - precision: 0.8967 - recall: 0.8967 - auc: 0.9563
# Epoch 33: val_loss did not improve from 0.05029
# 117/117 [==============================] - 95s 812ms/step - loss: 0.0533 - accuracy: 0.8967 - precision: 0.8967 - recall: 0.8967 - auc: 0.9563 - val_loss: 0.0535 - val_accuracy: 0.8996 - val_precision: 0.8996 - val_recall: 0.8996 - val_auc: 0.9583 - lr: 1.0000e-04
# Epoch 34/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0502 - accuracy: 0.9058 - precision: 0.9058 - recall: 0.9058 - auc: 0.9610
# Epoch 34: val_loss did not improve from 0.05029
# 117/117 [==============================] - 96s 815ms/step - loss: 0.0502 - accuracy: 0.9058 - precision: 0.9058 - recall: 0.9058 - auc: 0.9610 - val_loss: 0.0581 - val_accuracy: 0.8968 - val_precision: 0.8968 - val_recall: 0.8968 - val_auc: 0.9572 - lr: 1.0000e-04
# Epoch 35/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0502 - accuracy: 0.9053 - precision: 0.9053 - recall: 0.9053 - auc: 0.9609
# Epoch 35: val_loss did not improve from 0.05029
# 117/117 [==============================] - 95s 807ms/step - loss: 0.0502 - accuracy: 0.9053 - precision: 0.9053 - recall: 0.9053 - auc: 0.9609 - val_loss: 0.0533 - val_accuracy: 0.9015 - val_precision: 0.9015 - val_recall: 0.9015 - val_auc: 0.9606 - lr: 1.0000e-04
# Epoch 36/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0487 - accuracy: 0.9047 - precision: 0.9047 - recall: 0.9047 - auc: 0.9633
# Epoch 36: val_loss did not improve from 0.05029
# 117/117 [==============================] - 95s 812ms/step - loss: 0.0487 - accuracy: 0.9047 - precision: 0.9047 - recall: 0.9047 - auc: 0.9633 - val_loss: 0.0527 - val_accuracy: 0.8892 - val_precision: 0.8892 - val_recall: 0.8892 - val_auc: 0.9600 - lr: 1.0000e-04
# Epoch 37/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0487 - accuracy: 0.9055 - precision: 0.9055 - recall: 0.9055 - auc: 0.9637
# Epoch 37: val_loss did not improve from 0.05029
# 117/117 [==============================] - 96s 820ms/step - loss: 0.0487 - accuracy: 0.9055 - precision: 0.9055 - recall: 0.9055 - auc: 0.9637 - val_loss: 0.0519 - val_accuracy: 0.9015 - val_precision: 0.9015 - val_recall: 0.9015 - val_auc: 0.9609 - lr: 1.0000e-04
# Epoch 38/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0476 - accuracy: 0.9058 - precision: 0.9058 - recall: 0.9058 - auc: 0.9659
# Epoch 38: val_loss did not improve from 0.05029
# 117/117 [==============================] - 95s 813ms/step - loss: 0.0476 - accuracy: 0.9058 - precision: 0.9058 - recall: 0.9058 - auc: 0.9659 - val_loss: 0.0511 - val_accuracy: 0.9025 - val_precision: 0.9025 - val_recall: 0.9025 - val_auc: 0.9619 - lr: 2.0000e-05
# Epoch 39/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0477 - accuracy: 0.9064 - precision: 0.9064 - recall: 0.9064 - auc: 0.9655
# Epoch 39: val_loss did not improve from 0.05029
# 117/117 [==============================] - 94s 806ms/step - loss: 0.0477 - accuracy: 0.9064 - precision: 0.9064 - recall: 0.9064 - auc: 0.9655 - val_loss: 0.0534 - val_accuracy: 0.8968 - val_precision: 0.8968 - val_recall: 0.8968 - val_auc: 0.9591 - lr: 2.0000e-05
# Epoch 40/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0478 - accuracy: 0.9050 - precision: 0.9050 - recall: 0.9050 - auc: 0.9653
# Epoch 40: val_loss did not improve from 0.05029
# 117/117 [==============================] - 94s 804ms/step - loss: 0.0478 - accuracy: 0.9050 - precision: 0.9050 - recall: 0.9050 - auc: 0.9653 - val_loss: 0.0517 - val_accuracy: 0.8958 - val_precision: 0.8958 - val_recall: 0.8958 - val_auc: 0.9613 - lr: 2.0000e-05
# Epoch 41/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0483 - accuracy: 0.9037 - precision: 0.9037 - recall: 0.9037 - auc: 0.9652
# Epoch 41: val_loss did not improve from 0.05029
# 117/117 [==============================] - 101s 864ms/step - loss: 0.0483 - accuracy: 0.9037 - precision: 0.9037 - recall: 0.9037 - auc: 0.9652 - val_loss: 0.0520 - val_accuracy: 0.8977 - val_precision: 0.8977 - val_recall: 0.8977 - val_auc: 0.9606 - lr: 2.0000e-05
# Epoch 42/50
# 117/117 [==============================] - ETA: 0s - loss: 0.0472 - accuracy: 0.9061 - precision: 0.9061 - recall: 0.9061 - auc: 0.9662
# Epoch 42: val_loss did not improve from 0.05029
# 117/117 [==============================] - 95s 811ms/step - loss: 0.0472 - accuracy: 0.9061 - precision: 0.9061 - recall: 0.9061 - auc: 0.9662 - val_loss: 0.0508 - val_accuracy: 0.9006 - val_precision: 0.9006 - val_recall: 0.9006 - val_auc: 0.9633 - lr: 2.0000e-05
# Inception_model_history for split_70_20_10 saved as models/inception_model_history_split_70_20_10.pkl

# %%
from tensorflow.keras.models import load_model

# load model and loss function
model = load_model(
    'models/inception_model_split_70_20_10.h5',
    custom_objects={'focal_loss_fixed': focal_loss(gamma=2., alpha=0.75)}  
)

# evaluation
test_loss, test_accuracy, test_precision, test_recall, test_auc = model.evaluate(test_generator_70_20_10, verbose=1)

print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Precision: {test_precision}")
print(f"Test Recall: {test_recall}")
print(f"Test AUC: {test_auc}")
# Out:
# 17/17 [==============================] - 7s 182ms/step - loss: 0.0492 - accuracy: 0.9043 - precision: 0.9043 - recall: 0.9043 - auc: 0.9651
# Test Loss: 0.04918723553419113
# Test Accuracy: 0.904315173625946
# Test Precision: 0.904315173625946
# Test Recall: 0.904315173625946
# Test AUC: 0.965053141117096

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns
import os
import matplotlib.pyplot as plt


save_dir = r"C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\Inception"
os.makedirs(save_dir, exist_ok=True)

test_steps = test_generator_70_20_10.samples // test_generator_70_20_10.batch_size  
y_true = []
y_pred = []

# get prediction result
for _ in range(test_steps):
    x, y = test_generator_70_20_10.next()
    predictions = model.predict(x)
    
    # get true label
    y_true.extend(np.argmax(y, axis=1)) 
    # get prediction label
    y_pred.extend(np.argmax(predictions, axis=1))


# Confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Calculate sensitivity (Recall) and specificity
TP = cm[1, 1] 
TN = cm[0, 0]  
FP = cm[0, 1]  
FN = cm[1, 0]  

sensitivity = TP / float(TP + FN)
specificity = TN / float(TN + FP)

print(f'Sensitivity (Recall): {sensitivity}')
print(f'Specificity: {specificity}')

# Plot the confusion matrix
plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No Defect', 'Defect'], yticklabels=['No Defect', 'Defect'])
plt.title('Confusion Matrix of Inception', fontsize=14)
plt.xlabel('Predicted', fontsize=12)
plt.ylabel('True', fontsize=12)

# Save the confusion matrix plot
confusion_matrix_path = os.path.join(save_dir, 'confusion_matrix_inception.png')
plt.savefig(confusion_matrix_path, dpi=600, bbox_inches='tight')

# Print the saved path
print(f"Confusion matrix saved at: {confusion_matrix_path}")

# Show the plot
plt.show()
# Out:
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Sensitivity (Recall): 0.9977973568281938
# Specificity: 0.22413793103448276
# Confusion matrix saved at: C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\Inception\confusion_matrix_inception.png

# %%
from sklearn.metrics import f1_score
import numpy as np

test_steps = test_generator_70_20_10.samples // test_generator_70_20_10.batch_size
y_true = []
y_pred = []

for _ in range(test_steps):
    x, y = test_generator_70_20_10.next()
    predictions = model.predict(x)
    y_true.extend(np.argmax(y, axis=1))              
    y_pred.extend(np.argmax(predictions, axis=1))   

f1 = f1_score(y_true, y_pred, average='binary') 
print(f'F1 Score: {f1:.4f}')
# Out:
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# F1 Score: 0.9550

# %%
from tensorflow.keras.models import load_model

# load model and loss function
model = load_model(
    'models/inception_model_split_80_10_10.h5',
    custom_objects={'focal_loss_fixed': focal_loss(gamma=2., alpha=0.75)}  
)

# evaluation
test_loss, test_accuracy, test_precision, test_recall, test_auc = model.evaluate(test_generator_80_10_10, verbose=1)

print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Precision: {test_precision}")
print(f"Test Recall: {test_recall}")
print(f"Test AUC: {test_auc}")
# Out:
# 17/17 [==============================] - 9s 437ms/step - loss: 0.0471 - accuracy: 0.9123 - precision: 0.9123 - recall: 0.9123 - auc: 0.9675
# Test Loss: 0.04707873985171318
# Test Accuracy: 0.9123134613037109
# Test Precision: 0.9123134613037109
# Test Recall: 0.9123134613037109
# Test AUC: 0.9674603939056396
