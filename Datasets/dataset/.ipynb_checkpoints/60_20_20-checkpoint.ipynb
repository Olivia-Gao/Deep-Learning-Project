# %%
import os
import pandas as pd
import xml.etree.ElementTree as ET

# 数据路径
train_dir = r'C:\Users\xiaog\Desktop\Project\Datasets\dataset\split_60_20_20\train'
valid_dir = r'C:\Users\xiaog\Desktop\Project\Datasets\dataset\split_60_20_20\valid'
test_dir = r'C:\Users\xiaog\Desktop\Project\Datasets\dataset\split_60_20_20\test'

# %%
# get label
def get_label_from_xml(xml_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()
    objects = root.findall('object')

    # if exist "thermal_defect", return 1
    for obj in objects:
        if obj.find('name').text == 'thermal_defect':
            return "1" 

    return "0"  

# count defects
def count_defects_in_directory(data_dir):
    with_defect = 0
    without_defect = 0
    
    for root, _, files in os.walk(data_dir):
        for file in files:
            if file.endswith('.xml'):
                xml_path = os.path.join(root, file)
                img_path = os.path.join(root.replace('annotations', 'images'), file.replace('.xml', '.jpg'))

                if os.path.exists(img_path):  
                    label = get_label_from_xml(xml_path)  
                    if label == "1":
                        with_defect += 1
                    else:
                        without_defect += 1
    
    return with_defect, without_defect

def create_dataframe(data_dir):
    data = []
    
    for root, _, files in os.walk(data_dir):
        for file in files:
            if file.endswith('.xml'):
                xml_path = os.path.join(root, file)
                img_path = os.path.join(root.replace('annotations', 'images'), file.replace('.xml', '.jpg'))

                if os.path.exists(img_path): 
                    label = get_label_from_xml(xml_path) 
                    data.append([img_path, label])
    
    return pd.DataFrame(data, columns=['filepath', 'label'])

train_df = create_dataframe(train_dir)
valid_df = create_dataframe(valid_dir)
test_df = create_dataframe(test_dir)

print(f"Train set: {len(train_df)} images")
print(f"Valid set: {len(valid_df)} images")
print(f"Test set: {len(test_df)} images")

train_with_defect, train_without_defect = count_defects_in_directory(train_dir)
valid_with_defect, valid_without_defect = count_defects_in_directory(valid_dir)
test_with_defect, test_without_defect = count_defects_in_directory(test_dir)

print(f"Train set - defect: {train_with_defect}, no_defect: {train_without_defect}")
print(f"Valid set - defect: {valid_with_defect}, no_defect: {valid_without_defect}")
print(f"Test set - defect: {test_with_defect}, no_defect: {test_without_defect}")
# Out:
# Train set: 3211 images
# Valid set: 1070 images
# Test set: 1071 images
# Train set - defect: 2846, no_defect: 365
# Valid set - defect: 963, no_defect: 107
# Test set - defect: 924, no_defect: 147

# %%
import matplotlib.pyplot as plt

def plot_class_distribution(ax, with_defect, without_defect, title):
    ax.bar(['With Defect', 'Without Defect'], [with_defect, without_defect])
    ax.set_title(title)
    ax.set_ylabel('Count')

# Create a figure and set up subplots (1 row, 3 columns)
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Plot for Train Set
plot_class_distribution(axs[0], train_with_defect, train_without_defect, 'Train Set')

# Plot for Valid Set
plot_class_distribution(axs[1], valid_with_defect, valid_without_defect, 'Valid Set')

# Plot for Test Set
plot_class_distribution(axs[2], test_with_defect, test_without_defect, 'Test Set')

# Adjust layout for better spacing
plt.tight_layout()

# Save the figure
save_dir = r"C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_60_20_20"
class_distribution_path = os.path.join(save_dir, 'class_distribution_split_60_20_20.png')
plt.savefig(class_distribution_path, dpi=600, bbox_inches='tight')

# Print the saved path
print(f"Class distribution saved at: {class_distribution_path}")

# Show the plot
plt.show()
# Out:
# Class distribution saved at: C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_60_20_20\class_distribution_split_60_20_20.png

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

train_datagen = ImageDataGenerator(
    rescale=1./255,  
    rotation_range=30,  
    width_shift_range=0.2,  
    height_shift_range=0.2,  
    shear_range=0.2,  
    zoom_range=0.2, 
    horizontal_flip=True  
)

valid_test_datagen = ImageDataGenerator(rescale=1./255)

# train generator
train_generator_60_20_20 = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col="filepath",
    y_col="label",
    target_size=(128, 128),
    batch_size=32,
    class_mode="categorical"  
)

# valid generator
valid_generator_60_20_20 = valid_test_datagen.flow_from_dataframe(
    dataframe=valid_df,
    x_col="filepath",
    y_col="label",
    target_size=(128, 128),
    batch_size=32,
    class_mode="categorical"
)

# test generator
test_generator_60_20_20 = valid_test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col="filepath",
    y_col="label",
    target_size=(128, 128),
    batch_size=32,
    class_mode="categorical",
    shuffle=False  
)

print(f"Train generator samples: {train_generator_60_20_20.samples}")
print(f"Valid generator samples: {valid_generator_60_20_20.samples}")
print(f"Test generator samples: {test_generator_60_20_20.samples}")
# Out:
# Found 3211 validated image filenames belonging to 2 classes.
# Found 1070 validated image filenames belonging to 2 classes.
# Found 1071 validated image filenames belonging to 2 classes.
# Train generator samples: 3211
# Valid generator samples: 1070
# Test generator samples: 1071

# %%
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
import tensorflow as tf

def inception_module(x, filters):
    # 1x1 Conv
    conv1x1 = Conv2D(filters, (1,1), padding='same', activation='relu')(x)
    
    # 3x3 Conv
    conv3x3 = Conv2D(filters, (3,3), padding='same', activation='relu')(x)
    
    # 5x5 Conv
    conv5x5 = Conv2D(filters, (5,5), padding='same', activation='relu')(x)
    
    pool = MaxPooling2D((3,3), strides=(1,1), padding='same')(x)
    pool = Conv2D(filters, (1,1), padding='same', activation='relu')(pool)
    
    merged = concatenate([conv1x1, conv3x3, conv5x5, pool], axis=-1)
    return merged

def attention_block(inputs):
    attention = Dense(1, activation='tanh')(inputs)    # (batch_size, seq_length, 1)
    attention = Flatten()(attention)                   # (batch_size, seq_length)
    attention = Activation('softmax')(attention)       # (batch_size, seq_length)
    attention = Reshape((inputs.shape[1], 1))(attention)  # (batch_size, seq_length, 1)
    
    context = Multiply()([inputs, attention])          # (batch_size, seq_length, features)
    return context


def build_model(input_shape=(128, 128, 3), num_classes=2):
    inputs = Input(shape=input_shape)
    x = inception_module(inputs, 32)
    x = MaxPooling2D(2)(x)
    x = inception_module(x, 64)
    x = MaxPooling2D(2)(x)
    x = inception_module(x, 128)
    x = GlobalAveragePooling2D()(x)

    x = Reshape((-1, 128))(x)  # sequence for LSTM
    x = Bidirectional(LSTM(64, return_sequences=True))(x)
    x = Dropout(0.3)(x)
    x = attention_block(x)
    x = GlobalAveragePooling1D()(x)

    x = Dense(64, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs=inputs, outputs=outputs)
    return model
    # Build the model
model = build_model(input_shape=(128, 128, 3), num_classes=2)

# Print the model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 3)  0           ['input_1[0][0]']
#
#  conv2d (Conv2D)                (None, 128, 128, 32  128         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 32  896         ['input_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 32  2432        ['input_1[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 32  128         ['max_pooling2d[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 128, 128, 12  0           ['conv2d[0][0]',
#                                 8)                                'conv2d_1[0][0]',
#                                                                   'conv2d_2[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0          ['concatenate[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 128)  0          ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 64)   8256        ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 64)   73792       ['max_pooling2d_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 64)   204864      ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 64)   8256        ['max_pooling2d_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 256)  0           ['conv2d_4[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_6[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 256)  0          ['concatenate_1[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 32, 32, 256)  0          ['max_pooling2d_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 128)  32896       ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 128)  295040      ['max_pooling2d_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 128)  819328      ['max_pooling2d_3[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 128)  32896       ['max_pooling2d_4[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 32, 32, 512)  0           ['conv2d_8[0][0]',
#                                                                   'conv2d_9[0][0]',
#                                                                   'conv2d_10[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['concatenate_2[0][0]']
#  alAveragePooling2D)
#
#  reshape (Reshape)              (None, 4, 128)       0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  bidirectional (Bidirectional)  (None, 4, 128)       98816       ['reshape[0][0]']
#
#  dropout (Dropout)              (None, 4, 128)       0           ['bidirectional[0][0]']
#
#  dense (Dense)                  (None, 4, 1)         129         ['dropout[0][0]']
#
#  flatten (Flatten)              (None, 4)            0           ['dense[0][0]']
#
#  activation (Activation)        (None, 4)            0           ['flatten[0][0]']
#
#  reshape_1 (Reshape)            (None, 4, 1)         0           ['activation[0][0]']
#
#  multiply (Multiply)            (None, 4, 128)       0           ['dropout[0][0]',
#                                                                   'reshape_1[0][0]']
#
#  global_average_pooling1d (Glob  (None, 128)         0           ['multiply[0][0]']
#  alAveragePooling1D)
#
#  dense_1 (Dense)                (None, 64)           8256        ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dropout_1 (Dropout)            (None, 64)           0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 2)            130         ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 1,586,243
# Trainable params: 1,586,243
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Precision, Recall

def focal_loss(gamma=2., alpha=0.75):
    """
    Focal Loss implementation for binary classification.

    Parameters:
        gamma (float): Focusing parameter. Default is 2.
        alpha (float): Weighting factor for class imbalance. Default is 0.75 for better focusing on less frequent class.

    Returns:
        loss (function): Focal loss function.
    """

    def focal_loss_fixed(y_true, y_pred):
        # Clip predictions to avoid log(0)
        y_pred = K.clip(y_pred, K.epsilon(), 1. - K.epsilon())

        # Calculate cross entropy
        cross_entropy = -y_true * K.log(y_pred)

        # Calculate modulating factor (1 - p_t) ^ gamma
        modulating_factor = K.pow(1 - y_pred, gamma)

        # Calculate the focal loss
        loss = alpha * modulating_factor * cross_entropy

        return K.sum(loss, axis=-1)

    return focal_loss_fixed

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

def compile_model(model, split_name="split_60_20_20"):
    model.compile(
        optimizer=Adam(learning_rate=1e-4),
        loss=focal_loss(gamma=2., alpha=0.75),
        metrics=[
            'accuracy', 
            Precision(name='precision'), 
            Recall(name='recall'), 
            'AUC']
    )

    callbacks = [
        EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True),
        ModelCheckpoint(
            filepath=f'models/best_model_{split_name}.h5',
            monitor='val_loss',
            save_best_only=True,
            mode='min',
            verbose=1
        ),
        ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=10, min_lr=1e-6)
    ]

    return callbacks

# %%
import pickle
import numpy as np 

def train_and_save_history(train_generator, valid_generator, split_name="split_60_20_20", epochs=50, batch_size=32):
    steps_per_epoch = train_generator.samples // batch_size
    validation_steps = valid_generator.samples // batch_size

    # compile model
    model = build_model() 

    callbacks = compile_model(model, split_name)

    history = model.fit(
        train_generator,
        steps_per_epoch=steps_per_epoch,
        validation_data=valid_generator,
        validation_steps=validation_steps,
        epochs=epochs,
        callbacks=callbacks
    )

   # save history
    history_path = f"models/history_{split_name}.pkl"
    with open(history_path, 'wb') as f: 
        pickle.dump(history.history, f)

    print(f"Train history for {split_name} saved as {history_path}")


# train `split_60_20_20` and save history
train_and_save_history(train_generator_60_20_20, valid_generator_60_20_20, split_name="split_60_20_20")
# Out:
# Epoch 1/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0796 - accuracy: 0.8846 - precision: 0.8846 - recall: 0.8846 - auc: 0.8845
# Epoch 1: val_loss improved from inf to 0.06563, saving model to models\best_model_split_60_20_20.h5
# 100/100 [==============================] - 108s 765ms/step - loss: 0.0796 - accuracy: 0.8846 - precision: 0.8846 - recall: 0.8846 - auc: 0.8845 - val_loss: 0.0656 - val_accuracy: 0.9006 - val_precision: 0.9006 - val_recall: 0.9006 - val_auc: 0.9150 - lr: 1.0000e-04
# Epoch 2/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0706 - accuracy: 0.8864 - precision: 0.8864 - recall: 0.8864 - auc: 0.9024
# Epoch 2: val_loss improved from 0.06563 to 0.06370, saving model to models\best_model_split_60_20_20.h5
# 100/100 [==============================] - 89s 886ms/step - loss: 0.0706 - accuracy: 0.8864 - precision: 0.8864 - recall: 0.8864 - auc: 0.9024 - val_loss: 0.0637 - val_accuracy: 0.9006 - val_precision: 0.9006 - val_recall: 0.9006 - val_auc: 0.9413 - lr: 1.0000e-04
# Epoch 3/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0683 - accuracy: 0.8868 - precision: 0.8868 - recall: 0.8868 - auc: 0.9113
# Epoch 3: val_loss improved from 0.06370 to 0.06145, saving model to models\best_model_split_60_20_20.h5
# 100/100 [==============================] - 91s 907ms/step - loss: 0.0683 - accuracy: 0.8868 - precision: 0.8868 - recall: 0.8868 - auc: 0.9113 - val_loss: 0.0615 - val_accuracy: 0.9006 - val_precision: 0.9006 - val_recall: 0.9006 - val_auc: 0.9441 - lr: 1.0000e-04
# Epoch 4/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0654 - accuracy: 0.8874 - precision: 0.8874 - recall: 0.8874 - auc: 0.9263
# Epoch 4: val_loss did not improve from 0.06145
# 100/100 [==============================] - 93s 928ms/step - loss: 0.0654 - accuracy: 0.8874 - precision: 0.8874 - recall: 0.8874 - auc: 0.9263 - val_loss: 0.0637 - val_accuracy: 0.8996 - val_precision: 0.8996 - val_recall: 0.8996 - val_auc: 0.9505 - lr: 1.0000e-04
# Epoch 5/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0660 - accuracy: 0
- val_accuracy: 0.9167 - val_precision: 0.9167 - val_recall: 0.9167 - val_auc: 0.9721 - lr: 1.0000e-04
# Epoch 30/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0512 - accuracy: 0.9047 - precision: 0.9047 - recall: 0.9047 - auc: 0.9590
# Epoch 30: val_loss did not improve from 0.04468
# 100/100 [==============================] - 91s 903ms/step - loss: 0.0512 - accuracy: 0.9047 - precision: 0.9047 - recall: 0.9047 - auc: 0.9590 - val_loss: 0.0477 - val_accuracy: 0.9129 - val_precision: 0.9129 - val_recall: 0.9129 - val_auc: 0.9703 - lr: 1.0000e-04
# Epoch 31/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0502 - accuracy: 0.9069 - precision: 0.9069 - recall: 0.9069 - auc: 0.9616
# Epoch 31: val_loss did not improve from 0.04468
# 100/100 [==============================] - 92s 915ms/step - loss: 0.0502 - accuracy: 0.9069 - precision: 0.9069 - recall: 0.9069 - auc: 0.9616 - val_loss: 0.0450 - val_accuracy: 0.9176 - val_precision: 0.9176 - val_recall: 0.9176 - val_auc: 0.9704 - lr: 1.0000e-04
# Epoch 32/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0532 - accuracy: 0.9069 - precision: 0.9069 - recall: 0.9069 - auc: 0.9559
# Epoch 32: val_loss did not improve from 0.04468
# 100/100 [==============================] - 90s 900ms/step - loss: 0.0532 - accuracy: 0.9069 - precision: 0.9069 - recall: 0.9069 - auc: 0.9559 - val_loss: 0.0448 - val_accuracy: 0.9138 - val_precision: 0.9138 - val_recall: 0.9138 - val_auc: 0.9715 - lr: 1.0000e-04
# Epoch 33/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0517 - accuracy: 0.9056 - precision: 0.9056 - recall: 0.9056 - auc: 0.9589
# Epoch 33: val_loss did not improve from 0.04468
# 100/100 [==============================] - 89s 886ms/step - loss: 0.0517 - accuracy: 0.9056 - precision: 0.9056 - recall: 0.9056 - auc: 0.9589 - val_loss: 0.0554 - val_accuracy: 0.8883 - val_precision: 0.8883 - val_recall: 0.8883 - val_auc: 0.9586 - lr: 1.0000e-04
# Epoch 34/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0502 - accuracy: 0.9078 - precision: 0.9078 - recall: 0.9078 - auc: 0.9614
# Epoch 34: val_loss improved from 0.04468 to 0.04309, saving model to models\best_model_split_60_20_20.h5
# 100/100 [==============================] - 98s 974ms/step - loss: 0.0502 - accuracy: 0.9078 - precision: 0.9078 - recall: 0.9078 - auc: 0.9614 - val_loss: 0.0431 - val_accuracy: 0.9205 - val_precision: 0.9205 - val_recall: 0.9205 - val_auc: 0.9731 - lr: 1.0000e-04
# Epoch 35/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0504 - accuracy: 0.9069 - precision: 0.9069 - recall: 0.9069 - auc: 0.9609
# Epoch 35: val_loss did not improve from 0.04309
# 100/100 [==============================] - 92s 913ms/step - loss: 0.0504 - accuracy: 0.9069 - precision: 0.9069 - recall: 0.9069 - auc: 0.9609 - val_loss: 0.0448 - val_accuracy: 0.9195 - val_precision: 0.9195 - val_recall: 0.9195 - val_auc: 0.9722 - lr: 1.0000e-04
# Epoch 36/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0494 - accuracy: 0.9053 - precision: 0.9053 - recall: 0.9053 - auc: 0.9630
# Epoch 36: val_loss did not improve from 0.04309
# 100/100 [==============================] - 91s 910ms/step - loss: 0.0494 - accuracy: 0.9053 - precision: 0.9053 - recall: 0.9053 - auc: 0.9630 - val_loss: 0.0472 - val_accuracy: 0.9176 - val_precision: 0.9176 - val_recall: 0.9176 - val_auc: 0.9688 - lr: 1.0000e-04
# Epoch 37/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0509 - accuracy: 0.9081 - precision: 0.9081 - recall: 0.9081 - auc: 0.9599
# Epoch 37: val_loss did not improve from 0.04309
# 100/100 [==============================] - 91s 909ms/step - loss: 0.0509 - accuracy: 0.9081 - precision: 0.9081 - recall: 0.9081 - auc: 0.9599 - val_loss: 0.0444 - val_accuracy: 0.9138 - val_precision: 0.9138 - val_recall: 0.9138 - val_auc: 0.9712 - lr: 1.0000e-04
# Epoch 38/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0489 - accuracy: 0.9069 - precision: 0.9069 - recall: 0.9069 - auc: 0.9638
# Epoch 38: val_loss did not improve from 0.04309
# 100/100 [==============================] - 90s 901ms/step - loss: 0.0489 - accuracy: 0.9069 - precision: 0.9069 - recall: 0.9069 - auc: 0.9638 - val_loss: 0.0461 - val_accuracy: 0.9167 - val_precision: 0.9167 - val_recall: 0.9167 - val_auc: 0.9702 - lr: 1.0000e-04
# Epoch 39/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0510 - accuracy: 0.9056 - precision: 0.9056 - recall: 0.9056 - auc: 0.9602
# Epoch 39: val_loss did not improve from 0.04309
# 100/100 [==============================] - 87s 870ms/step - loss: 0.0510 - accuracy: 0.9056 - precision: 0.9056 - recall: 0.9056 - auc: 0.9602 - val_loss: 0.0435 - val_accuracy: 0.9223 - val_precision: 0.9223 - val_recall: 0.9223 - val_auc: 0.9724 - lr: 1.0000e-04
# Epoch 40/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0491 - accuracy: 0.9088 - precision: 0.9088 - recall: 0.9088 - auc: 0.9630
# Epoch 40: val_loss did not improve from 0.04309
# 100/100 [==============================] - 89s 885ms/step - loss: 0.0491 - accuracy: 0.9088 - precision: 0.9088 - recall: 0.9088 - auc: 0.9630 - val_loss: 0.0449 - val_accuracy: 0.9157 - val_precision: 0.9157 - val_recall: 0.9157 - val_auc: 0.9707 - lr: 1.0000e-04
# Epoch 41/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0491 - accuracy: 0.9085 - precision: 0.9085 - recall: 0.9085 - auc: 0.9634
# Epoch 41: val_loss did not improve from 0.04309
# 100/100 [==============================] - 90s 897ms/step - loss: 0.0491 - accuracy: 0.9085 - precision: 0.9085 - recall: 0.9085 - auc: 0.9634 - val_loss: 0.0443 - val_accuracy: 0.9157 - val_precision: 0.9157 - val_recall: 0.9157 - val_auc: 0.9713 - lr: 1.0000e-04
# Epoch 42/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0479 - accuracy: 0.9056 - precision: 0.9056 - recall: 0.9056 - auc: 0.9646
# Epoch 42: val_loss improved from 0.04309 to 0.04258, saving model to models\best_model_split_60_20_20.h5
# 100/100 [==============================] - 89s 889ms/step - loss: 0.0479 - accuracy: 0.9056 - precision: 0.9056 - recall: 0.9056 - auc: 0.9646 - val_loss: 0.0426 - val_accuracy: 0.9205 - val_precision: 0.9205 - val_recall: 0.9205 - val_auc: 0.9735 - lr: 1.0000e-04
# Epoch 43/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0482 - accuracy: 0.9097 - precision: 0.9097 - recall: 0.9097 - auc: 0.9647
# Epoch 43: val_loss did not improve from 0.04258
# 100/100 [==============================] - 91s 906ms/step - loss: 0.0482 - accuracy: 0.9097 - precision: 0.9097 - recall: 0.9097 - auc: 0.9647 - val_loss: 0.0430 - val_accuracy: 0.9223 - val_precision: 0.9223 - val_recall: 0.9223 - val_auc: 0.9731 - lr: 1.0000e-04
# Epoch 44/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0483 - accuracy: 0.9103 - precision: 0.9103 - recall: 0.9103 - auc: 0.9646
# Epoch 44: val_loss improved from 0.04258 to 0.04253, saving model to models\best_model_split_60_20_20.h5
# 100/100 [==============================] - 91s 910ms/step - loss: 0.0483 - accuracy: 0.9103 - precision: 0.9103 - recall: 0.9103 - auc: 0.9646 - val_loss: 0.0425 - val_accuracy: 0.9186 - val_precision: 0.9186 - val_recall: 0.9186 - val_auc: 0.9735 - lr: 1.0000e-04
# Epoch 45/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0483 - accuracy: 0.9069 - precision: 0.9069 - recall: 0.9069 - auc: 0.9651
# Epoch 45: val_loss did not improve from 0.04253
# 100/100 [==============================] - 91s 908ms/step - loss: 0.0483 - accuracy: 0.9069 - precision: 0.9069 - recall: 0.9069 - auc: 0.9651 - val_loss: 0.0475 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9679 - lr: 1.0000e-04
# Epoch 46/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0476 - accuracy: 0.9097 - precision: 0.9097 - recall: 0.9097 - auc: 0.9655
# Epoch 46: val_loss improved from 0.04253 to 0.04238, saving model to models\best_model_split_60_20_20.h5
# 100/100 [==============================] - 89s 889ms/step - loss: 0.0476 - accuracy: 0.9097 - precision: 0.9097 - recall: 0.9097 - auc: 0.9655 - val_loss: 0.0424 - val_accuracy: 0.9148 - val_precision: 0.9148 - val_recall: 0.9148 - val_auc: 0.9739 - lr: 1.0000e-04
# Epoch 47/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0478 - accuracy: 0.9113 - precision: 0.9113 - recall: 0.9113 - auc: 0.9653
# Epoch 47: val_loss did not improve from 0.04238
# 100/100 [==============================] - 89s 890ms/step - loss: 0.0478 - accuracy: 0.9113 - precision: 0.9113 - recall: 0.9113 - auc: 0.9653 - val_loss: 0.0456 - val_accuracy: 0.9148 - val_precision: 0.9148 - val_recall: 0.9148 - val_auc: 0.9700 - lr: 1.0000e-04
# Epoch 48/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0473 - accuracy: 0.9053 - precision: 0.9053 - recall: 0.9053 - auc: 0.9661
# Epoch 48: val_loss did not improve from 0.04238
# 100/100 [==============================] - 89s 891ms/step - loss: 0.0473 - accuracy: 0.9053 - precision: 0.9053 - recall: 0.9053 - auc: 0.9661 - val_loss: 0.0425 - val_accuracy: 0.9195 - val_precision: 0.9195 - val_recall: 0.9195 - val_auc: 0.9742 - lr: 1.0000e-04
# Epoch 49/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0473 - accuracy: 0.9100 - precision: 0.9100 - recall: 0.9100 - auc: 0.9656
# Epoch 49: val_loss improved from 0.04238 to 0.04203, saving model to models\best_model_split_60_20_20.h5
# 100/100 [==============================] - 91s 902ms/step - loss: 0.0473 - accuracy: 0.9100 - precision: 0.9100 - recall: 0.9100 - auc: 0.9656 - val_loss: 0.0420 - val_accuracy: 0.9214 - val_precision: 0.9214 - val_recall: 0.9214 - val_auc: 0.9748 - lr: 1.0000e-04
# Epoch 50/50
# 100/100 [==============================] - ETA: 0s - loss: 0.0485 - accuracy: 0.9110 - precision: 0.9110 - recall: 0.9110 - auc: 0.9642
# Epoch 50: val_loss did not improve from 0.04203
# 100/100 [==============================] - 89s 885ms/step - loss: 0.0485 - accuracy: 0.9110 - precision: 0.9110 - recall: 0.9110 - auc: 0.9642 - val_loss: 0.0430 - val_accuracy: 0.9214 - val_precision: 0.9214 - val_recall: 0.9214 - val_auc: 0.9729 - lr: 1.0000e-04
# Train history for split_60_20_20 saved as models/history_split_60_20_20.pkl

# %%
import matplotlib.pyplot as plt
import pickle
import os

# load history
history_path = "models/history_split_60_20_20.pkl"  
with open(history_path, 'rb') as f:
    history = pickle.load(f)
    
# Plot training and validation loss and acc
acc = history['accuracy']
val_acc = history['val_accuracy']
loss = history['loss']
val_loss = history['val_loss']

epochs = range(1, len(acc) + 1)

# Define the directory to save the image
save_dir = r"C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_60_20_20"
os.makedirs(save_dir, exist_ok=True)  # Ensure the directory exists

plt.figure(figsize=(12, 4))
# Plot training and validation accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs, acc, label='Training Accuracy')
plt.plot(epochs, val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy', fontsize=16)
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.legend()
accuracy_path = os.path.join(save_dir, 'accuracy_curve_split_60_20_20.png')
plt.savefig(accuracy_path, dpi=600, bbox_inches='tight')
print(f"Accuracy curve saved at: {accuracy_path}")


# Plot training and validation loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.title('Training and Validation Loss', fontsize=16)
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Loss', fontsize=12)
plt.legend()
loss_path = os.path.join(save_dir, 'loss_curve_split_60_20_20.png')
plt.savefig(loss_path, dpi=600, bbox_inches='tight')
print(f"Loss curve saved at: {loss_path}")

plt.show()
# Out:
# Accuracy curve saved at: C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_60_20_20\accuracy_curve_split_60_20_20.png
# Loss curve saved at: C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_60_20_20\loss_curve_split_60_20_20.png

# %%
import matplotlib.pyplot as plt
import pickle

# load history
history_path = 'models/history_split_60_20_20.pkl'  
with open(history_path, 'rb') as f:
    history_dict = pickle.load(f)

def plot_precision_recall(history):
    if 'precision' not in history or 'recall' not in history:
        print("No precision or recall data found in history!")
        return

    save_dir = r"C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_60_20_20"
    os.makedirs(save_dir, exist_ok=True)  
    
    plt.figure(figsize=(12, 4))
    
    # Precision plot
    plt.subplot(1, 2, 1)
    plt.plot(history['precision'], label='Train Precision')
    plt.plot(history['val_precision'], label='Validation Precision')
    plt.title('Precision', fontsize=16)
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Precision', fontsize=12)
    plt.legend()

    # Recall plot
    plt.subplot(1, 2, 2)
    plt.plot(history['recall'], label='Train Recall')
    plt.plot(history['val_recall'], label='Validation Recall')
    plt.title('Recall', fontsize=16)
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Recall', fontsize=12)
    plt.legend()

    plt.tight_layout()

    # Save the figure
    precision_recall_path = os.path.join(save_dir, 'precision_recall_curve_split_60_20_20.png')
    plt.savefig(precision_recall_path, dpi=600, bbox_inches='tight')
    print(f"Precision and Recall curve saved at: {precision_recall_path}")
    
    plt.show()


plot_precision_recall(history_dict)
# Out:
# Precision and Recall curve saved at: C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_60_20_20\precision_recall_curve_split_60_20_20.png

# %%
import matplotlib.pyplot as plt
import pickle

# load history
history_path = 'models/history_split_60_20_20.pkl' 
with open(history_path, 'rb') as f:
    history_dict = pickle.load(f)
    
def plot_auc(history):
    if 'auc' not in history or 'val_auc' not in history:
        print("No AUC data found in history!")
        return
    save_dir = r"C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_60_20_20"
    os.makedirs(save_dir, exist_ok=True) 
    
    plt.figure(figsize=(12, 4))

    # AUC plot
    plt.plot(history['auc'], label='Train AUC')
    plt.plot(history['val_auc'], label='Validation AUC')
    plt.title('AUC', fontsize=16)
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('AUC', fontsize=12)
    plt.legend()

    auc_path = os.path.join(save_dir, 'auc_curve_split_60_20_20.png')
    plt.savefig(auc_path, dpi=600, bbox_inches='tight')
    print(f"AUC curve saved at: {auc_path}")

    plt.show()


plot_auc(history_dict)
# Out:
# AUC curve saved at: C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_60_20_20\auc_curve_split_60_20_20.png

# %%
from tensorflow.keras.models import load_model

# load model and loss function
model = load_model(
    'models/best_model_split_60_20_20.h5',
    custom_objects={'focal_loss_fixed': focal_loss(gamma=2., alpha=0.75)}  
)

# evaluation
test_loss, test_accuracy, test_precision, test_recall, test_auc = model.evaluate(test_generator_60_20_20, verbose=1)

print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Precision: {test_precision}")
print(f"Test Recall: {test_recall}")
print(f"Test AUC: {test_auc}")
# Out:
# 34/34 [==============================] - 18s 422ms/step - loss: 0.0559 - accuracy: 0.8870 - precision: 0.8870 - recall: 0.8870 - auc: 0.9544
# Test Loss: 0.05592900514602661
# Test Accuracy: 0.8870214819908142
# Test Precision: 0.8870214819908142
# Test Recall: 0.8870214819908142
# Test AUC: 0.95439612865448

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns
import os

save_dir = r"C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_60_20_20"
os.makedirs(save_dir, exist_ok=True)

test_steps = test_generator_60_20_20.samples // test_generator_60_20_20.batch_size  
y_true = []
y_pred = []

# get prediction result
for _ in range(test_steps):
    x, y = test_generator_60_20_20.next()
    predictions = model.predict(x)
    
    # get true label
    y_true.extend(np.argmax(y, axis=1)) 
    # get prediction label
    y_pred.extend(np.argmax(predictions, axis=1))


# Confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Calculate sensitivity (Recall) and specificity
TP = cm[1, 1] 
TN = cm[0, 0]  
FP = cm[0, 1]  
FN = cm[1, 0]  

sensitivity = TP / float(TP + FN)
specificity = TN / float(TN + FP)

print(f'Sensitivity (Recall): {sensitivity}')
print(f'Specificity: {specificity}')

# Plot the confusion matrix
plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No Defect', 'Defect'], yticklabels=['No Defect', 'Defect'])
plt.title('Confusion Matrix of split_60_20_20', fontsize=14)
plt.xlabel('Predicted', fontsize=12)
plt.ylabel('True', fontsize=12)

# Save the confusion matrix plot
confusion_matrix_path = os.path.join(save_dir, 'confusion_matrix_split_60_20_20.png')
plt.savefig(confusion_matrix_path, dpi=600, bbox_inches='tight')

# Print the saved path
print(f"Confusion matrix saved at: {confusion_matrix_path}")

# Show the plot
plt.show()
# Out:
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 61ms/step
# Sensitivity (Recall): 0.9736842105263158
# Specificity: 0.3472222222222222
# Confusion matrix saved at: C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_60_20_20\confusion_matrix_split_60_20_20.png

# %%
from sklearn.metrics import f1_score
import numpy as np

test_steps = test_generator_60_20_20.samples // test_generator_60_20_20.batch_size
y_true = []
y_pred = []

for _ in range(test_steps):
    x, y = test_generator_60_20_20.next()
    predictions = model.predict(x)
    y_true.extend(np.argmax(y, axis=1))              
    y_pred.extend(np.argmax(predictions, axis=1))   

f1 = f1_score(y_true, y_pred, average='binary')  
print(f'F1 Score: {f1:.4f}')
# Out:
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# F1 Score: 0.9392

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt
import numpy as np
import os

save_dir = r"C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_60_20_20"
os.makedirs(save_dir, exist_ok=True)

test_steps = test_generator_60_20_20.samples // test_generator_60_20_20.batch_size

y_true = []
y_scores = []

for _ in range(test_steps):
    x_batch, y_batch = test_generator_60_20_20.next()
    preds = model.predict(x_batch)

    y_true.extend(np.argmax(y_batch, axis=1))
    
    y_scores.extend(preds[:, 1])

precision, recall, thresholds = precision_recall_curve(y_true, y_scores)

plt.figure(figsize=(6, 4))
plt.plot(recall, precision, label='Precision-Recall Curve', color='darkorange')
plt.xlabel('Recall', fontsize=12)
plt.ylabel('Precision', fontsize=12)
plt.title('Precision-Recall Curve (Defect Detection)', fontsize=16)
plt.legend(loc="lower left")
plt.grid(True)

# Corrected variable name
precision_recall_curve_path = os.path.join(save_dir, 'precision-recall_curve_split_60_20_20.png')
plt.savefig(precision_recall_curve_path, dpi=600, bbox_inches='tight')
print(f"Precision_Recall Curve saved at: {precision_recall_curve_path}")

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 74ms/step
# Precision_Recall Curve saved at: C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_60_20_20\precision-recall_curve_split_60_20_20.png

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
import numpy as np

save_dir = r"C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_60_20_20"
os.makedirs(save_dir, exist_ok=True)

test_steps = test_generator_60_20_20.samples // test_generator_60_20_20.batch_size

y_true = []
y_scores = []

for _ in range(test_steps):
    x_batch, y_batch = test_generator_60_20_20.next()
    preds = model.predict(x_batch)

    y_true.extend(np.argmax(y_batch, axis=1))

    y_scores.extend(preds[:, 1])

# calculate ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)

# ROC curve
plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC Curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random Guessing')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=12)
plt.ylabel('True Positive Rate', fontsize=12)
plt.title('ROC Curve - Defect Detection', fontsize=16)
plt.legend(loc="lower right")
plt.grid(True)

ROC_Curve_path = os.path.join(save_dir, 'roc_curve_split_60_20_20.png')
plt.savefig(confusion_matrix_path, dpi=600, bbox_inches='tight')
print(f"ROC Curve saved at: {ROC_Curve_path}")

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 75ms/step
# ROC Curve saved at: C:\Users\xiaog\Desktop\Project\Datasets\dataset\Performance\split_60_20_20\roc_curve_split_60_20_20.png
